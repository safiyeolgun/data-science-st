# %% [markdown]
# # 🏦 Churn Prediction in HR Data: A Machine Learning-Deep Learning Approach 🤖
# ___

# %% [markdown]
# # New Section

# %% [markdown]
# <img src="https://media.licdn.com/dms/image/D4E12AQHx9u8uVrzkHA/article-cover_image-shrink_720_1280/0/1676512042467?e=2147483647&v=beta&t=dyGSrVDd2O4_CJmh4jfasi0baUJ8GhaCzzfqbSLTT_E" alt="Churn Prediction in Banking" width="75%" height="75%">
#
# [Credit](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.linkedin.com%2Fpulse%2Fstop-employee-turnover-chris-timol&psig=AOvVaw3W4yU_TQx7RxGvc_Z58ojS&ust=1699990935532000&source=images&cd=vfe&opi=89978449&ved=0CBQQjhxqFwoTCPi1k_LdwYIDFQAAAAAdAAAAABAv)

# %% [markdown]
# # Content
#
# <div>
#   <ul >
#     <li><a href="#part_5">PART - 5 PREPARATION ANALYSIS</a></li>
#     <li><a href="#part_6">PART - 6 DEEP LEARNING: ANN ANALYSIS </a></li>
#     <li><a href="#part_7">PART - 7 COMPARE MODELS PERFORMANCES </a></li>
#     </ul>
# </div>

# %% [markdown]
# <a id="part_5"></a>

# %% [markdown]
# # ✨ PART - 5 Preparation Analysis ✨

# %% [markdown]
# ## Part 5- Sub Content
# <div class="list-group" id="list-tab" role="tablist">
# <ul><li><a class="list-group-item list-group-item-action" data-toggle="list" href="#part_1_dataset" role="tab" aria-controls="profile">5.1. Dataset Explanation </a> </li>
#   <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#part_1_importing" role="tab" aria-controls="messages"> 5.2. Importing Libraries</a> </li>
#  <li><a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_1_def" role="tab" aria-controls="settings"> 5.3. User Defined Functions (DEFs) </a></li>
#  <li><a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_1_reading" role="tab" aria-controls="settings"> 5.4. Reading & Understanding Data </a> </li>
#  <li><a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_1_data_integrity" role="tab" aria-controls="settings"> 5.5. Data Integrity Checks </a> </li>
#
# </ul>
# </div>

# %% [markdown]
# ## 5.1. Dataset Explanation
#
# ***Dataset Overview:*** The dataset contains information about employees in a company, focusing on various attributes that can impact employee retention. The features include employee satisfaction, performance evaluation, number of projects, average monthly hours worked, years of experience, work accidents, promotions, department, salary level, and the target variable "left" indicating whether the employee has left the company.
#
# - ***satisfaction_level:*** It is employee satisfaction point, which ranges from 0-1.
# - ***last_evaluation:*** It is evaluated performance by the employer, which also ranges from 0-1.
# - ***number_projects:*** How many of projects assigned to an employee?
# - ***average_monthly_hours:*** How many hours in averega an employee worked in a month?
# - **time_spent_company:** time_spent_company means employee experience. The number of years spent by an employee in the company.
# - ***work_accident:*** Whether an employee has had a work accident or not.
# - ***promotion_last_5years:*** Whether an employee has had a promotion in the last 5 years or not.
# - ***Departments:*** Employee's working department/division.
# - ***Salary:*** Salary level of the employee such as low, medium and high.
# - ***left:*** Whether the employee has left the company or not.

# %% [markdown]
# ## 5.2. Importing Libraries

# %%
# !pip install scikeras
# !pip install scikit-plot
# !pip install livelossplot
# !pip install optuna

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import os

from sklearn.compose import ColumnTransformer


from sklearn.metrics import accuracy_score, average_precision_score,\
                            classification_report, confusion_matrix, f1_score, \
                            precision_score, precision_recall_curve, \
                            recall_score, RocCurveDisplay, roc_auc_score, roc_curve

from sklearn.model_selection import cross_validate, cross_val_score, GridSearchCV, \
                                    RandomizedSearchCV, train_test_split

from sklearn.preprocessing import MinMaxScaler, OneHotEncoder, OrdinalEncoder

from sklearn.utils.class_weight import compute_class_weight

from scikitplot.metrics import average_precision_score, plot_roc, precision_recall_curve

from scikeras.wrappers import KerasClassifier

from tensorflow import keras
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.layers import Activation, Dense
from tensorflow.keras.models import load_model, Sequential
from tensorflow.keras.optimizers import Adam, Adadelta, Nadam, RMSprop

# from keras.metrics import BinaryAccuracy, Precision, Recall, F1Score
from livelossplot import PlotLossesKerasTF

import optuna
import pickle

# %%
plt.rcParams["figure.figsize"] = (10, 6)

sns.set_style("whitegrid")
pd.set_option("display.float_format", lambda x: "%.3f" % x)

# Set it to None to display all columns in the dataframe:
pd.set_option("display.max_columns", None)

# %%
# Uncomment the following lines if you want to suppress warnings:
import warnings
warnings.filterwarnings("ignore")
warnings.warn("this will not show")

# %%
# version control
import matplotlib
import sklearn
import tensorflow as tf

# !python --version # python version
print()
print("Pandas ", pd.__version__)
print("NumPy ", np.__version__)
print("Matplotlib ", matplotlib.__version__)
print("Seaborn ", sns.__version__)
print("Scikit-Learn ", sklearn.__version__)
print("Tensor-Flow ", tf.__version__)
# Out:
# Python 3.10.12
#
# Pandas  1.5.3
# NumPy  1.23.5
# Matplotlib  3.7.1
# Seaborn  0.12.2
# Scikit-Learn  1.2.2
# Tensor-Flow  2.14.0

# %% [markdown]
# ## 5.3. User Defined Functions (DEFs)

# %%
# confusion matrix

def con_matrix(X_train, X_test, y_train, y_test, model, model_name='model'):

  y_pred = (model.predict(X_test) > 0.5).astype('int64')
  print(f'{model_name} - Test Confusion Matrix\n' + '*' * 50)
  print(confusion_matrix(y_test, y_pred))
  print(classification_report(y_test, y_pred))

  print()

  y_train_pred = (model.predict(X_train) > 0.5).astype('int64')
  print(f'{model_name} - Train Confusion Matrix\n' + '*' * 50)
  print(confusion_matrix(y_train, y_train_pred))
  print(classification_report(y_train, y_train_pred))

# model tuning for cross validation

def build_classifier():
    classifier = Sequential()
    classifier.add(Dense(units=26, activation="relu", input_dim=X_train.shape[1]))
    classifier.add(Dense(units=13, activation="relu"))
    classifier.add(Dense(units=5, activation="relu"))
    classifier.add(Dense(units=1, activation="sigmoid"))
    classifier.compile(
        optimizer="adam", loss="binary_crossentropy", metrics=['accuracy']
    )
    return classifier

# %%
# for optuna model selection

def create_model(trial):

    n_units1 = trial.suggest_int("n_units1", 8, 128)
    n_units2 = trial.suggest_int("n_units2", 8, 128)
    n_units3 = trial.suggest_int("n_units3", 8, 128)
    n_units4 = trial.suggest_int("n_units4", 8, 128)

    optimizer = trial.suggest_categorical("optimizer", [Adam, Adadelta, RMSprop, Nadam])

    learning_rate = trial.suggest_loguniform("learning_rate", 1e-6, 1e-1)

    model = Sequential()
    model.add(Dense(n_units1, input_dim=X_train.shape[1], activation="relu"))
    model.add(Dense(n_units2, activation="relu"))
    model.add(Dense(n_units3, activation="relu"))
    model.add(Dense(n_units4, activation="relu"))

    model.add(Dense(1, activation="sigmoid"))

    model.compile(loss="binary_crossentropy",
                  optimizer=optimizer(learning_rate=learning_rate),
                  metrics=[trial_metric]
    )
    return model


def objective(trial):
    model = create_model(trial)
    w0 = trial.suggest_loguniform("w0", 0.001, 5)
    w1 = trial.suggest_loguniform("w1", 0.001, 5)

    model.fit(X_train,
              y_train,
              validation_data=(X_val, y_val),
              batch_size=batch_size,
              epochs=epochs,
              callbacks=[early_stop],
              class_weight={0: w0, 1: w1},
              verbose=0,
              )

    if len(trial_metric) == 1:
      _, accuracy = model.evaluate(X_train, y_train, verbose=0)
      if accuracy > .86 :   # after this threshold model gets terrible scores for class 0
        accuracy = accuracy * 0
        return accuracy
      else:
        return accuracy

    elif len(trial_metric) == 2:
        _, accuracy, recall = model.evaluate(X_train, y_train, verbose=0)
        return accuracy, recall

# %%
# optuna model fit

def model_fit(params, X_train, y_train, X_val, y_val):
  unit1, unit2, unit3, unit4, optimizer, lr, w0, w1 = best_params.values()

  optuna = Sequential()
  optuna.add(Dense(unit1, activation="relu"))
  optuna.add(Dense(unit2, activation="relu"))
  optuna.add(Dense(unit3, activation="relu"))
  optuna.add(Dense(unit4, activation="relu"))
  optuna.add(Dense(1, activation="sigmoid"))

  opt = optimizer(learning_rate=lr)

  optuna.compile(optimizer=opt, loss="binary_crossentropy", metrics=['accuracy', 'Precision', 'Recall'])

  # train model
  optuna.fit(X_train,
             y_train,
             validation_data=(X_val, y_val),
             batch_size=batch_size,
             epochs=epochs,
             callbacks=[early_stop],
             class_weight={0: w0, 1: w1},
             verbose=1)
  return optuna

# %% [markdown]
# ## 5.4. Reading & Understanding Data

# %%
# this is not orginal dataset, it has been processed from EDA

df0 = pd.read_csv('HR_Dataset_DL.csv')

# %%
df = df0.copy()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11991 entries, 0 to 11990
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     11991 non-null  float64
#  1   last_evaluation        11991 non-null  float64
#  2   number_project         11991 non-null  int64
#  3   average_montly_hours   11991 non-null  int64
#  4   time_spend_company     11991 non-null  int64
#  5   work_accident          11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotion_last_5years  11991 non-null  int64
#  8   departments            11991 non-null  object
#  9   salary                 11991 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 936.9+ KB

# %%
df.head()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0               0.380            0.530               2                   157
# 1               0.800            0.860               5                   262
# 2               0.110            0.880               7                   272
# 3               0.720            0.870               5                   223
# 4               0.370            0.520               2                   159
#
#    time_spend_company  work_accident  left  promotion_last_5years departments  \
# 0                   3              0     1                      0       sales
# 1                   6              0     1                      0       sales
# 2                   4              0     1                      0       sales
# 3                   5              0     1                      0       sales
# 4                   3              0     1                      0       sales
#
#    salary
# 0     low
# 1  medium
# 2  medium
# 3     low
# 4     low

# %% [markdown]
# <a id="part_6"></a>

# %% [markdown]
# # ✨ PART - 6 Deep Learning: ANN Analysis ✨

# %% [markdown]
# ## Part 6- Sub Content
# <div class="list-group" id="list-tab" role="tablist">
#   <ul>
#    <li><a class="list-group-item list-group-item-action" data-toggle="list" href="#part_1_dataset" role="tab" aria-controls="profile">  6.0. Data Preprocessing</a></li>
#
# <ul>
#
# </ul>
#
#
#   <li><a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_vanilla" role="tab" aria-controls="settings"> 6.1. Vanilla  ✨</a></li>
#   <ul>
#  <li><a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_1_data_integrity" role="tab" aria-controls="settings">    6.0.1. Data Integrity Checks </a> </li>
# </ul>
#
#   <li><a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_vanill_LR003" role="tab" aria-controls="settings"> 6.2. Vanilla Learning Rate 0.003  ✨ </a></li>
#
#   <li><a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_vanill_LR003ES" role="tab" aria-controls="settings"> 6.3. Vanilla Learning Rate 0.003 Early Stoping  ✨ </a></li>
#
#   <li><a class="list-group-item list-group-item-action"  data-toggle="list" href="#part_5_optuna" role="tab" aria-controls="settings"> 6.4. Optuna   ✨</a></li>
#
#
# </ul>
# </div>

# %% [markdown]
# ## 6.1. Data Preprocessing

# %%
seed = 42
os.environ["TF_DETERMINISTIC_OPS"] = "1"
keras.utils.set_random_seed(seed)

# %%
df['left'].value_counts(normalize = True)
# Out:
# 0   0.834
# 1   0.166
# Name: left, dtype: float64

# %%
X = df.drop(columns = ['left'])
y = df['left']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    stratify=y,
                                                    test_size=0.1,
                                                    random_state=seed)
X_train, X_val, y_train, y_val = train_test_split(X_train,
                                                  y_train,
                                                  stratify=y_train,
                                                  test_size=0.15,
                                                  random_state=seed)

# %%
print("X_train shape", X_train.shape)
print("X_val shape", X_val.shape)
print("X_test shape",X_test.shape)
# Out:
# X_train shape (9172, 9)
# X_val shape (1619, 9)
# X_test shape (1200, 9)

# %%
print("y_train shape", y_train.shape)
print("y_val shape", y_val.shape)
print("y_test shape",y_test.shape)
# Out:
# y_train shape (9172,)
# y_val shape (1619,)
# y_test shape (1200,)

# %%
X_train.head()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 7024               0.680            0.610               3
# 8697               0.640            0.790               4
# 9673               0.220            1.000               6
# 2394               0.480            0.690               4
# 6583               0.820            0.520               5
#
#       average_montly_hours  time_spend_company  work_accident  \
# 7024                   134                   4              0
# 8697                   274                   2              1
# 9673                   244                   3              0
# 2394                   222                   2              0
# 6583                   225                   2              0
#
#       promotion_last_5years departments  salary
# 7024                      0       sales  medium
# 8697                      0   technical     low
# 9673                      0          IT  medium
# 2394                      0   technical  medium
# 6583                      0  accounting    high

# %%
# ordinal encoding for salary column

ordinal = OrdinalEncoder(categories = [['low', 'medium', 'high']])

X_train['salary'] = ordinal.fit_transform(X_train[['salary']])
X_val['salary'] = ordinal.transform(X_val[['salary']])
X_test  ['salary'] = ordinal.transform(X_test[['salary']])

# %%
X_train.salary.value_counts()
# Out:
# 0.000    4396
# 1.000    4005
# 2.000     771
# Name: salary, dtype: int64

# %%
# onehot encoding for departments columns

encoder = OneHotEncoder(categories='auto',
                        sparse=False,
                        drop='first',
                        handle_unknown="ignore")

transformers = [('dept', encoder, ['departments'])]

col_transformer = ColumnTransformer(transformers=transformers,
                                    remainder=MinMaxScaler())

# %%
# using col_transformer for one hot encoding to train_dataset

transformed_data = pd.DataFrame(col_transformer.fit_transform(X_train))


transformed_data.columns = col_transformer.get_feature_names_out(input_features=X_train.columns )

transformed_data.columns =  [col.split('__')[-1] for col in transformed_data.columns]
X_train = transformed_data
X_train.head()
# Out:
#    departments_RandD  departments_accounting  departments_hr  \
# 0              0.000                   0.000           0.000
# 1              0.000                   0.000           0.000
# 2              0.000                   0.000           0.000
# 3              0.000                   0.000           0.000
# 4              0.000                   1.000           0.000
#
#    departments_management  departments_marketing  departments_product_mng  \
# 0                   0.000                  0.000                    0.000
# 1                   0.000                  0.000                    0.000
# 2                   0.000                  0.000                    0.000
# 3                   0.000                  0.000                    0.000
# 4                   0.000                  0.000                    0.000
#
#    departments_sales  departments_support  departments_technical  \
# 0              1.000                0.000                  0.000
# 1              0.000                0.000                  1.000
# 2              0.000                0.000                  0.000
# 3              0.000                0.000                  1.000
# 4              0.000                0.000                  0.000
#
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0               0.648            0.391           0.200                 0.178
# 1               0.604            0.672           0.400                 0.832
# 2               0.143            1.000           0.800                 0.692
# 3               0.429            0.516           0.400                 0.589
# 4               0.802            0.250           0.600                 0.603
#
#    time_spend_company  work_accident  promotion_last_5years  salary
# 0               0.250          0.000                  0.000   0.500
# 1               0.000          1.000                  0.000   0.000
# 2               0.125          0.000                  0.000   0.500
# 3               0.000          0.000                  0.000   0.500
# 4               0.000          0.000                  0.000   1.000

# %%
# using col_transformer for one hot encoding to val_dataset

transformed_data = pd.DataFrame(col_transformer.transform(X_val))


transformed_data.columns = col_transformer.get_feature_names_out(input_features=X_val.columns )

transformed_data.columns =  [col.split('__')[-1] for col in transformed_data.columns]
X_val = transformed_data
X_val.head()
# Out:
#    departments_RandD  departments_accounting  departments_hr  \
# 0              0.000                   0.000           0.000
# 1              0.000                   0.000           0.000
# 2              0.000                   0.000           0.000
# 3              0.000                   0.000           0.000
# 4              0.000                   0.000           1.000
#
#    departments_management  departments_marketing  departments_product_mng  \
# 0                   0.000                  0.000                    0.000
# 1                   0.000                  0.000                    0.000
# 2                   0.000                  1.000                    0.000
# 3                   0.000                  0.000                    0.000
# 4                   0.000                  0.000                    0.000
#
#    departments_sales  departments_support  departments_technical  \
# 0              0.000                1.000                  0.000
# 1              1.000                0.000                  0.000
# 2              0.000                0.000                  0.000
# 3              0.000                1.000                  0.000
# 4              0.000                0.000                  0.000
#
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0               0.516            0.594           0.200                 0.790
# 1               0.165            0.313           0.400                 0.864
# 2               0.330            0.281           0.000                 0.164
# 3               0.989            0.328           0.200                 0.374
# 4               0.363            0.219           0.000                 0.201
#
#    time_spend_company  work_accident  promotion_last_5years  salary
# 0               0.125          0.000                  0.000   0.500
# 1               0.625          0.000                  0.000   0.500
# 2               0.125          0.000                  0.000   0.000
# 3               0.250          1.000                  0.000   0.500
# 4               0.125          0.000                  0.000   0.500

# %%
# using col_transformer for one hot encoding to test_dataset

transformed_data = pd.DataFrame(col_transformer.transform(X_test))


transformed_data.columns = col_transformer.get_feature_names_out(input_features=X_test.columns )

transformed_data.columns =  [col.split('__')[-1] for col in transformed_data.columns]
X_test = transformed_data
X_test.head()
# Out:
#    departments_RandD  departments_accounting  departments_hr  \
# 0              0.000                   0.000           0.000
# 1              0.000                   1.000           0.000
# 2              0.000                   0.000           0.000
# 3              0.000                   0.000           0.000
# 4              0.000                   0.000           0.000
#
#    departments_management  departments_marketing  departments_product_mng  \
# 0                   0.000                  0.000                    0.000
# 1                   0.000                  0.000                    0.000
# 2                   0.000                  0.000                    0.000
# 3                   0.000                  0.000                    1.000
# 4                   0.000                  0.000                    0.000
#
#    departments_sales  departments_support  departments_technical  \
# 0              0.000                1.000                  0.000
# 1              0.000                0.000                  0.000
# 2              0.000                0.000                  1.000
# 3              0.000                0.000                  0.000
# 4              1.000                0.000                  0.000
#
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0               0.560            0.422           0.600                 0.799
# 1               0.011            0.750           0.600                 0.967
# 2               0.901            0.109           0.400                 0.098
# 3               0.473            0.688           0.200                 0.729
# 4               0.747            0.094           0.400                 0.009
#
#    time_spend_company  work_accident  promotion_last_5years  salary
# 0               0.125          0.000                  0.000   0.000
# 1               0.375          0.000                  0.000   0.500
# 2               0.375          1.000                  0.000   0.500
# 3               0.250          0.000                  0.000   0.000
# 4               0.000          0.000                  0.000   0.000

# %%
print("X_train shape", X_train.shape)
print("X_val shape", X_val.shape)
print("X_test shape",X_test.shape)
# Out:
# X_train shape (9172, 17)
# X_val shape (1619, 17)
# X_test shape (1200, 17)

# %%
# converting all label dataset into float32

y_train = y_train.astype('float32')
y_val = y_val.astype('float32')
y_test = y_test.astype('float32')

# %%
batch_size = 64
epochs = 1000
patience = 30

# %% [markdown]
# <a id="part_5_vanilla"></a>

# %% [markdown]
# ## 6.1. Vanilla ✨

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:black;background-color:#3498DB;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;background-color:#3498DB; ">Content</a>

# %%
vanilla = Sequential()

vanilla.add(Dense(26, activation='relu', input_dim=X_train.shape[1])) #17*1,5
vanilla.add(Dense(13, activation='relu'))
vanilla.add(Dense(5, activation='relu'))
vanilla.add(Dense(1, activation='sigmoid'))

vanilla.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy', 'Precision', 'Recall'])

# %%
vanilla.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 26)                468
#
#  dense_1 (Dense)             (None, 13)                351
#
#  dense_2 (Dense)             (None, 5)                 70
#
#  dense_3 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 895 (3.50 KB)
# Trainable params: 895 (3.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
class_weights = compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)
class_weights_dict = dict(enumerate(class_weights))

# %%
print('Balanced weight')
print(f'w0: {class_weights_dict[0]}')
print(f'w1: {class_weights_dict[1]}')
# Out:
# Balanced weight
# w0: 0.5995554974506472
# w1: 3.011162179908076

# %%
vanilla.fit(x=X_train,
            y=y_train,
            validation_data=(X_val,y_val),
            batch_size=batch_size,
            epochs=epochs,
            verbose=1,
            callbacks=[PlotLossesKerasTF()],
            class_weight=class_weights_dict )
# Out:
# accuracy
# 	training         	 (min:    0.418, max:    0.989, cur:    0.987)
# 	validation       	 (min:    0.520, max:    0.968, cur:    0.957)
# Loss
# 	training         	 (min:    0.037, max:    0.659, cur:    0.040)
# 	validation       	 (min:    0.137, max:    0.736, cur:    0.325)
# precision
# 	training         	 (min:    0.213, max:    0.951, cur:    0.943)
# 	validation       	 (min:    0.248, max:    0.904, cur:    0.847)
# recall
# 	training         	 (min:    0.915, max:    0.987, cur:    0.984)
# 	validation       	 (min:    0.866, max:    0.941, cur:    0.903)
# 144/144 [==============================] - 2s 14ms/step - loss: 0.0405 - accuracy: 0.9875 - precision: 0.9428 - recall: 0.9842 - val_loss: 0.3250 - val_accuracy: 0.9568 - val_precision: 0.8467 - val_recall: 0.9033

# %%
vanilla.save('DL_vanilla.h5')

# %%
vanilla_loss_df = pd.DataFrame(vanilla.history.history)
vanilla_loss_df.tail()
# Out:
#      loss  accuracy  precision  recall  val_loss  val_accuracy  val_precision  \
# 995 0.038     0.987      0.942   0.986     0.345         0.959          0.864
# 996 0.040     0.986      0.938   0.981     0.336         0.957          0.864
# 997 0.040     0.987      0.939   0.986     0.324         0.960          0.873
# 998 0.044     0.986      0.936   0.984     0.348         0.959          0.856
# 999 0.040     0.987      0.943   0.984     0.325         0.957          0.847
#
#      val_recall
# 995       0.896
# 996       0.877
# 997       0.892
# 998       0.903
# 999       0.903

# %%
vanilla_loss_df.plot(subplots=[['loss','val_loss'],
                            ['accuracy','val_accuracy'],
                            ['precision', 'val_precision'],
                            ['recall', 'val_recall']],
                            layout=(2,2),
                            figsize=(12,6));

# %%
loss, accuracy, precision, recall = vanilla.evaluate(X_test, y_test, verbose=0)
print("vanilla test loss: ", loss)
print("vanilla test accuracy: ", accuracy)
print("vanilla test precision ", precision)
print("vanilla test recall: ", recall)
# Out:
# vanilla test loss:  0.30723896622657776
# vanilla test accuracy:  0.9616666436195374
# vanilla test precision  0.8558139801025391
# vanilla test recall:  0.9246231317520142

# %%
loss, accuracy, precision, recall = vanilla.evaluate(X_train, y_train, verbose=0)
print("vanilla train loss: ", loss)
print("vanilla train accuracy: ", accuracy)
print("vanilla train precision ", precision)
print("vanilla train recall: ", recall)
# Out:
# vanilla train loss:  0.04047880694270134
# vanilla train accuracy:  0.9865896105766296
# vanilla train precision  0.9364089965820312
# vanilla train recall:  0.9862114191055298

# %%
con_matrix(X_train, X_test, y_train, y_test, vanilla, 'Vanilla')
# Out:
# 38/38 [==============================] - 0s 3ms/step
# Vanilla - Test Confusion Matrix
# **************************************************
# [[970  31]
#  [ 15 184]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.97      0.98      1001
#          1.0       0.86      0.92      0.89       199
#
#     accuracy                           0.96      1200
#    macro avg       0.92      0.95      0.93      1200
# weighted avg       0.96      0.96      0.96      1200
#
#
# 287/287 [==============================] - 1s 3ms/step
# Vanilla - Train Confusion Matrix
# **************************************************
# [[7547  102]
#  [  21 1502]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99      7649
#          1.0       0.94      0.99      0.96      1523
#
#     accuracy                           0.99      9172
#    macro avg       0.97      0.99      0.98      9172
# weighted avg       0.99      0.99      0.99      9172

# %%
y_pred_proba1 = vanilla.predict(X_test)
y_pred_proba_train1 = vanilla.predict(X_train)

y_pred1 =  (vanilla.predict(X_test) > .5).astype("int32")
y_pred_train1 = (vanilla.predict(X_train) > .5).astype("int32")

print("Average Test Precision Score:  ", average_precision_score(y_test, y_pred_proba1))
print("Average Train Precision Score: ", average_precision_score(y_train, y_pred_proba_train1))
print("F1 Test Precision Score: ", f1_score(y_test, y_pred1))
print("F1 Train Precision Score:",f1_score(y_train, y_pred_train1))
print("Recall Test Precision Score: ", recall_score(y_test, y_pred1))
print("Recall Train Precision Score:",recall_score(y_train, y_pred_train1))
# Out:
# 38/38 [==============================] - 0s 3ms/step
# 287/287 [==============================] - 1s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 287/287 [==============================] - 1s 2ms/step
# Average Test Precision Score:   0.91087738831655
# Average Train Precision Score:  0.9962016678957899
# F1 Test Precision Score:  0.8888888888888888
# F1 Train Precision Score: 0.9606651742884554
# Recall Test Precision Score:  0.9246231155778895
# Recall Train Precision Score: 0.9862114248194354

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# ROC curve for the test data
RocCurveDisplay.from_predictions(y_test, y_pred_proba1, ax=axes[0])
axes[0].set_title('Test ROC Curve')

# ROC curve for the train data
RocCurveDisplay.from_predictions(y_train, y_pred_proba_train1, ax=axes[1])
axes[1].set_title('Train ROC Curve')
plt.tight_layout();

# %%
plt.figure(figsize=(12, 6))

# Precision-recall curve for the test data
precisions_test, recalls_test, thresholds_test = precision_recall_curve(y_test, y_pred_proba1)
plt.subplot(1, 2, 1)  # Arrange two plots side by side, this is the first plot
plt.plot(recalls_test, precisions_test, label='ANN')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (Test)')

# Precision-recall curve for the train data
precisions_train, recalls_train, thresholds_train = precision_recall_curve(y_train, y_pred_proba_train1)
plt.subplot(1, 2, 2)  # Arrange two plots side by side, this is the second plot
plt.plot(recalls_train, precisions_train, label='ANN')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (Train)')

plt.tight_layout();

# %% [markdown]
# ### 6.1.1. Vanilla Evaluating and Tuning

# %%
classifier_model = KerasClassifier(
                                    model=build_classifier,
                                    batch_size=batch_size,
                                    epochs=100,
                                    verbose=0)

scores = cross_validate(
    estimator=classifier_model,
    X=X_train,
    y=y_train,
    scoring=["accuracy", "precision", "recall", "f1"],
    cv=10,
    return_train_score=True
)

df_scores_cv = pd.DataFrame(scores, index=range(1, 11)).iloc[:, 2:]

df_scores_cv
# Out:
#     test_accuracy  train_accuracy  test_precision  train_precision  \
# 1           0.968           0.978           0.937            0.963
# 2           0.967           0.977           0.907            0.946
# 3           0.968           0.974           0.913            0.943
# 4           0.973           0.979           0.964            0.974
# 5           0.964           0.979           0.910            0.959
# 6           0.963           0.979           0.910            0.954
# 7           0.968           0.977           0.897            0.957
# 8           0.968           0.972           0.897            0.919
# 9           0.962           0.975           0.893            0.938
# 10          0.966           0.973           0.907            0.935
#
#     test_recall  train_recall  test_f1  train_f1
# 1         0.869         0.901    0.902     0.931
# 2         0.895         0.915    0.901     0.930
# 3         0.895         0.899    0.904     0.920
# 4         0.868         0.897    0.913     0.934
# 5         0.868         0.914    0.889     0.936
# 6         0.862         0.915    0.885     0.934
# 7         0.914         0.901    0.906     0.928
# 8         0.914         0.910    0.906     0.915
# 9         0.875         0.912    0.884     0.925
# 10        0.889         0.901    0.898     0.917

# %%
df_scores_summary = pd.DataFrame({
        "test_mean": df_scores_cv.mean().values[[0,2,4,6]],
        "test_std": df_scores_cv.std().values[[0,2,4,6]],
        "train_mean": df_scores_cv.mean().values[[1,3,5,7]],
        "train_std": df_scores_cv.std().values[[1,3,5,7]]
        }, index=["accuracy", "precision", "recall", "f1"])

df_scores_summary
# Out:
#            test_mean  test_std  train_mean  train_std
# accuracy       0.967     0.003       0.976      0.003
# precision      0.913     0.021       0.949      0.016
# recall         0.885     0.019       0.906      0.007
# f1             0.899     0.010       0.927      0.007

# %% [markdown]
# <a id="part_5_vanill_LR003"></a>

# %% [markdown]
# ## 6.2. Vanilla Learning Rate 0.003 ✨

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:black;background-color:#3498DB;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;background-color:#3498DB; ">Content</a>

# %%
vanilla_LR_0_003 = Sequential()

vanilla_LR_0_003.add(Dense(26, activation='relu', input_dim=X_train.shape[1])) #17*1,5
vanilla_LR_0_003.add(Dense(13, activation='relu'))
vanilla_LR_0_003.add(Dense(5, activation='relu'))
vanilla_LR_0_003.add(Dense(1, activation='sigmoid'))

opt = Adam(learning_rate=0.003)
vanilla_LR_0_003.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy', 'Precision', 'Recall'])

# %%
vanilla_LR_0_003.fit(x=X_train,
                     y=y_train,
                     validation_data=(X_val,y_val),
                     batch_size=batch_size,
                     epochs=epochs,
                     verbose=1,
                     callbacks=[PlotLossesKerasTF()],
                     class_weight=class_weights_dict )
# Out:
# accuracy
# 	training         	 (min:    0.655, max:    0.990, cur:    0.990)
# 	validation       	 (min:    0.800, max:    0.966, cur:    0.956)
# Loss
# 	training         	 (min:    0.034, max:    0.577, cur:    0.034)
# 	validation       	 (min:    0.133, max:    0.503, cur:    0.320)
# precision
# 	training         	 (min:    0.292, max:    0.953, cur:    0.948)
# 	validation       	 (min:    0.447, max:    0.896, cur:    0.841)
# recall
# 	training         	 (min:    0.755, max:    0.992, cur:    0.991)
# 	validation       	 (min:    0.855, max:    0.933, cur:    0.903)
# 144/144 [==============================] - 2s 13ms/step - loss: 0.0336 - accuracy: 0.9896 - precision: 0.9485 - recall: 0.9915 - val_loss: 0.3200 - val_accuracy: 0.9555 - val_precision: 0.8408 - val_recall: 0.9033

# %%
vanilla_LR_0_003.save('DL_vanilla_LR_0_003.h5')

# %%
vanilla_LR_0_003_loss_df = pd.DataFrame(vanilla_LR_0_003.history.history)
vanilla_LR_0_003_loss_df.tail()
# Out:
#      loss  accuracy  precision  recall  val_loss  val_accuracy  val_precision  \
# 995 0.039     0.987      0.934   0.989     0.321         0.955          0.833
# 996 0.040     0.987      0.934   0.989     0.319         0.959          0.856
# 997 0.036     0.988      0.939   0.990     0.304         0.958          0.848
# 998 0.036     0.987      0.942   0.986     0.307         0.957          0.844
# 999 0.034     0.990      0.948   0.991     0.320         0.956          0.841
#
#      val_recall
# 995       0.911
# 996       0.903
# 997       0.911
# 998       0.907
# 999       0.903

# %%
vanilla_LR_0_003_loss_df.plot(subplots=[['loss','val_loss'],
                                        ['accuracy','val_accuracy'],
                                        ['precision', 'val_precision'],
                                        ['recall', 'val_recall']],
                                        layout=(2,2),
                                        figsize=(12,6));

# %%
loss, accuracy, precision, recall = vanilla_LR_0_003.evaluate(X_test, y_test, verbose=0)
print("vanilla LR 0.003 test loss: ", loss)
print("vanilla LR 0.003 test accuracy: ", accuracy)
print("vanilla LR 0.003 test precision ", precision)
print("vanilla LR 0.003 test recall: ", recall)
# Out:
# vanilla LR 0.003 test loss:  0.2671464681625366
# vanilla LR 0.003 test accuracy:  0.9608333110809326
# vanilla LR 0.003 test precision  0.8584905862808228
# vanilla LR 0.003 test recall:  0.9145728349685669

# %%
loss, accuracy, precision, recall = vanilla_LR_0_003.evaluate(X_train, y_train, verbose=0)
print("vanilla LR 0.003 train loss: ", loss)
print("vanilla LR 0.003 train accuracy: ", accuracy)
print("vanilla LR 0.003 train precision ", precision)
print("vanilla LR 0.003 train recall: ", recall)
# Out:
# vanilla LR 0.003 train loss:  0.03427642583847046
# vanilla LR 0.003 train accuracy:  0.9889882206916809
# vanilla LR 0.003 train precision  0.9477329850196838
# vanilla LR 0.003 train recall:  0.9881812334060669

# %%
con_matrix(X_train, X_test, y_train, y_test, vanilla_LR_0_003, 'vanilla LR 0.003')
# Out:
# 38/38 [==============================] - 0s 2ms/step
# vanilla LR 0.003 - Test Confusion Matrix
# **************************************************
# [[971  30]
#  [ 17 182]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.97      0.98      1001
#          1.0       0.86      0.91      0.89       199
#
#     accuracy                           0.96      1200
#    macro avg       0.92      0.94      0.93      1200
# weighted avg       0.96      0.96      0.96      1200
#
#
# 287/287 [==============================] - 0s 2ms/step
# vanilla LR 0.003 - Train Confusion Matrix
# **************************************************
# [[7566   83]
#  [  18 1505]]
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      0.99      7649
#          1.0       0.95      0.99      0.97      1523
#
#     accuracy                           0.99      9172
#    macro avg       0.97      0.99      0.98      9172
# weighted avg       0.99      0.99      0.99      9172

# %%
y_pred_proba2 = vanilla_LR_0_003.predict(X_test)
y_pred_proba_train2 = vanilla_LR_0_003.predict(X_train)

y_pred2 =  (vanilla_LR_0_003.predict(X_test) > .5).astype("int32")
y_pred_train2 =  (vanilla_LR_0_003.predict(X_train) > .5).astype("int32")

print("Average Test Precision Score:  ", average_precision_score(y_test, y_pred_proba2))
print("Average Train Precision Score: ", average_precision_score(y_train, y_pred_proba_train2))
print("F1 Test Precision Score: ", f1_score(y_test, y_pred2))
print("F1 Train Precision Score:",f1_score(y_train, y_pred_train2))
print("Recall Test Precision Score: ", recall_score(y_test, y_pred2))
print("Recall Train Precision Score:",recall_score(y_train, y_pred_train2))
# Out:
# 38/38 [==============================] - 0s 2ms/step
# 287/287 [==============================] - 1s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 287/287 [==============================] - 1s 2ms/step
# Average Test Precision Score:   0.9325566975280212
# Average Train Precision Score:  0.9962197967043316
# F1 Test Precision Score:  0.8856447688564478
# F1 Train Precision Score: 0.9675345548055286
# Recall Test Precision Score:  0.914572864321608
# Recall Train Precision Score: 0.9881812212738017

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# ROC curve for the test data
RocCurveDisplay.from_predictions(y_test, y_pred_proba2, ax=axes[0])
axes[0].set_title('Test ROC Curve')

# ROC curve for the train data
RocCurveDisplay.from_predictions(y_train, y_pred_proba_train2, ax=axes[1])
axes[1].set_title('Train ROC Curve')
plt.tight_layout();

# %%
plt.figure(figsize=(12, 6))

# Precision-recall curve for the test data
precisions_test, recalls_test, thresholds_test = precision_recall_curve(y_test, y_pred_proba2)
plt.subplot(1, 2, 1)  # Arrange two plots side by side, this is the first plot
plt.plot(recalls_test, precisions_test, label='ANN')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (Test)')

# Precision-recall curve for the train data
precisions_train, recalls_train, thresholds_train = precision_recall_curve(y_train, y_pred_proba_train2)
plt.subplot(1, 2, 2)  # Arrange two plots side by side, this is the second plot
plt.plot(recalls_train, precisions_train, label='ANN')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (Train)')

plt.tight_layout();

# %% [markdown]
# <a id="part_5_vanill_LR003_ES"></a>

# %% [markdown]
# ## 6.3. Vanilla Learning Rate 0.003 Early Stopping ✨

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:black;background-color:#3498DB;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;background-color:#3498DB; ">Content</a>

# %%
vanilla_LR_0_003_ES = Sequential()

vanilla_LR_0_003_ES.add(Dense(26, activation='relu', input_dim=X_train.shape[1])) #17*1,5
vanilla_LR_0_003_ES.add(Dense(13, activation='relu'))
vanilla_LR_0_003_ES.add(Dense(5, activation='relu'))
vanilla_LR_0_003_ES.add(Dense(1, activation='sigmoid'))

opt = Adam(learning_rate=0.003)
vanilla_LR_0_003_ES.compile(optimizer=opt, loss='binary_crossentropy', metrics=['accuracy', 'Precision', 'Recall'])

# %%
early_stop = EarlyStopping(monitor="val_loss", mode="auto", verbose=1, patience=patience, restore_best_weights=True)

# %%
vanilla_LR_0_003_ES.fit(x=X_train,
                        y=y_train,
                        validation_data=(X_val,y_val),
                        batch_size=batch_size,
                        epochs=epochs,
                        verbose=1,
                        callbacks=[early_stop, PlotLossesKerasTF()],
                        class_weight=class_weights_dict )
# Out:
# accuracy
# 	training         	 (min:    0.763, max:    0.962, cur:    0.960)
# 	validation       	 (min:    0.746, max:    0.960, cur:    0.953)
# Loss
# 	training         	 (min:    0.117, max:    0.603, cur:    0.117)
# 	validation       	 (min:    0.139, max:    0.536, cur:    0.168)
# precision
# 	training         	 (min:    0.356, max:    0.838, cur:    0.830)
# 	validation       	 (min:    0.387, max:    0.857, cur:    0.814)
# recall
# 	training         	 (min:    0.532, max:    0.958, cur:    0.958)
# 	validation       	 (min:    0.911, max:    0.944, cur:    0.929)
# 144/144 [==============================] - 2s 13ms/step - loss: 0.1170 - accuracy: 0.9604 - precision: 0.8299 - recall: 0.9580 - val_loss: 0.1683 - val_accuracy: 0.9531 - val_precision: 0.8143 - val_recall: 0.9294
# Epoch 68: early stopping

# %%
vanilla_LR_0_003_ES.save('DL_vanilla_LR_0_003_ES.h5')

# %%
vanilla_LR_0_003_ES_loss_df = pd.DataFrame(vanilla_LR_0_003_ES.history.history)
vanilla_LR_0_003_ES_loss_df.tail()
# Out:
#     loss  accuracy  precision  recall  val_loss  val_accuracy  val_precision  \
# 63 0.117     0.962      0.838   0.955     0.176         0.945          0.783
# 64 0.118     0.959      0.825   0.955     0.185         0.944          0.775
# 65 0.119     0.958      0.825   0.950     0.171         0.949          0.797
# 66 0.119     0.961      0.831   0.958     0.168         0.949          0.800
# 67 0.117     0.960      0.830   0.958     0.168         0.953          0.814
#
#     val_recall
# 63       0.926
# 64       0.933
# 65       0.933
# 66       0.922
# 67       0.929

# %%
vanilla_LR_0_003_ES_loss_df.plot(subplots=[['loss','val_loss'],
                                           ['accuracy','val_accuracy'],
                                           ['precision', 'val_precision'],
                                           ['recall', 'val_recall']],
                                           layout=(2,2),
                                           figsize=(12,6));

# %%
loss, accuracy, precision, recall = vanilla_LR_0_003_ES.evaluate(X_test, y_test, verbose=0)
print("vanilla LR 0.03 early stop test loss: ", loss)
print("vanilla LR 0.03 early stop test accuracy: ", accuracy)
print("vanilla LR 0.03 early stop test precision ", precision)
print("vanilla LR 0.03 early stop test recall: ", recall)
# Out:
# vanilla LR 0.03 early stop test loss:  0.13285411894321442
# vanilla LR 0.03 early stop test accuracy:  0.9608333110809326
# vanilla LR 0.03 early stop test precision  0.855140209197998
# vanilla LR 0.03 early stop test recall:  0.9195979833602905

# %%
loss, accuracy, precision, recall = vanilla_LR_0_003_ES.evaluate(X_train, y_train, verbose=0)
print("vanilla LR 0.03 early stop train loss: ", loss)
print("vanilla LR 0.03 early stop train accuracy: ", accuracy)
print("vanilla LR 0.03 early stop train precision ", precision)
print("vanilla LR 0.03 early stop train recall: ", recall)
# Out:
# vanilla LR 0.03 early stop train loss:  0.09957735240459442
# vanilla LR 0.03 early stop train accuracy:  0.9674007892608643
# vanilla LR 0.03 early stop train precision  0.8858764171600342
# vanilla LR 0.03 early stop train recall:  0.9225213527679443

# %%
con_matrix(X_train, X_test, y_train, y_test, vanilla_LR_0_003_ES, 'Vanilla LR 0.003 Early Stop')
# Out:
# 38/38 [==============================] - 0s 2ms/step
# Vanilla LR 0.003 Early Stop - Test Confusion Matrix
# **************************************************
# [[970  31]
#  [ 16 183]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.97      0.98      1001
#          1.0       0.86      0.92      0.89       199
#
#     accuracy                           0.96      1200
#    macro avg       0.92      0.94      0.93      1200
# weighted avg       0.96      0.96      0.96      1200
#
#
# 287/287 [==============================] - 0s 2ms/step
# Vanilla LR 0.003 Early Stop - Train Confusion Matrix
# **************************************************
# [[7468  181]
#  [ 118 1405]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.98      0.98      7649
#          1.0       0.89      0.92      0.90      1523
#
#     accuracy                           0.97      9172
#    macro avg       0.94      0.95      0.94      9172
# weighted avg       0.97      0.97      0.97      9172

# %%
y_pred_proba3 = vanilla_LR_0_003_ES.predict(X_test)
y_pred_proba_train3 = vanilla_LR_0_003_ES.predict(X_train)

y_pred3 =  (vanilla_LR_0_003_ES.predict(X_test) > .5).astype("int32")
y_pred_train3 =  (vanilla_LR_0_003_ES.predict(X_train) > .5).astype("int32")

print("Average Test Precision Score:  ", average_precision_score(y_test, y_pred_proba3))
print("Average Train Precision Score: ", average_precision_score(y_train, y_pred_proba_train3))
print("F1 Test Precision Score: ", f1_score(y_test, y_pred3))
print("F1 Train Precision Score:",f1_score(y_train, y_pred_train3))
print("Recall Test Precision Score: ", recall_score(y_test, y_pred3))
print("Recall Train Precision Score:",recall_score(y_train, y_pred_train3))
# Out:
# 38/38 [==============================] - 0s 2ms/step
# 287/287 [==============================] - 0s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 287/287 [==============================] - 0s 2ms/step
# Average Test Precision Score:   0.9384333402868799
# Average Train Precision Score:  0.955034602630864
# F1 Test Precision Score:  0.8861985472154965
# F1 Train Precision Score: 0.9038275972981666
# Recall Test Precision Score:  0.9195979899497487
# Recall Train Precision Score: 0.922521339461589

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# ROC curve for the test data
RocCurveDisplay.from_predictions(y_test, y_pred_proba3, ax=axes[0])
axes[0].set_title('Test ROC Curve')

# ROC curve for the train data
RocCurveDisplay.from_predictions(y_train, y_pred_proba_train3, ax=axes[1])
axes[1].set_title('Train ROC Curve')
plt.tight_layout();

# %%
plt.figure(figsize=(12, 6))

# Precision-recall curve for the test data
precisions_test, recalls_test, thresholds_test = precision_recall_curve(y_test, y_pred_proba3)
plt.subplot(1, 2, 1)  # Arrange two plots side by side, this is the first plot
plt.plot(recalls_test, precisions_test, label='ANN')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (Test)')

# Precision-recall curve for the train data
precisions_train, recalls_train, thresholds_train = precision_recall_curve(y_train, y_pred_proba_train3)
plt.subplot(1, 2, 2)  # Arrange two plots side by side, this is the second plot
plt.plot(recalls_train, precisions_train, label='ANN')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (Train)')

plt.tight_layout();

# %% [markdown]
# <a id="part_5_optuna"></a>

# %% [markdown]
# ## 6.4. Optuna  ✨

# %% [markdown]
# <a href="#part_5" class="btn btn-danger btn-lg active" role="button" aria-pressed="true" style="color:black;background-color:#3498DB;">Part - 5</a>
# <a href="#toc" class="btn btn-warning btn-lg active" role="button" aria-pressed="true" style="color:black;background-color:#3498DB; ">Content</a>

# %%
trial_metric = ['accuracy', 'Recall']

# %%
if len(trial_metric) == 1:
    # single value optimization
    study = optuna.create_study(direction="maximize") # accuracy

# multiple value optimization
elif len(trial_metric) == 2:
    study = optuna.create_study(directions=["maximize", "maximize"])

study.optimize(objective, n_trials=10, show_progress_bar = True)
# Out:
# [I 2023-11-27 08:49:12,943] A new study created in memory with name: no-name-62a71cf7-4369-4905-b808-aa14055a6eb6
#   0%|          | 0/10 [00:00<?, ?it/s]
# Restoring model weights from the end of the best epoch: 87.
# Epoch 117: early stopping
# [I 2023-11-27 08:50:06,340] Trial 0 finished with values: [0.9660924673080444, 0.7977675795555115] and parameters: {'n_units1': 47, 'n_units2': 91, 'n_units3': 29, 'n_units4': 69, 'optimizer': <class 'keras.src.optimizers.adam.Adam'>, 'learning_rate': 0.009516316390714147, 'w0': 1.3127955200256611, 'w1': 0.02401777042259833}.
# [I 2023-11-27 08:58:30,231] Trial 1 finished with values: [0.8835586309432983, 0.4589625597000122] and parameters: {'n_units1': 114, 'n_units2': 8, 'n_units3': 114, 'n_units4': 62, 'optimizer': <class 'keras.src.optimizers.adam.Adam'>, 'learning_rate': 1.5727957487797862e-06, 'w0': 0.002489300918117918, 'w1': 0.0018544171044489696}.
# Restoring model weights from the end of the best epoch: 19.
# Epoch 49: early stopping
# [I 2023-11-27 08:59:12,969] Trial 2 finished with values: [0.8339511752128601, 0.0] and parameters: {'n_units1': 103, 'n_units2': 67, 'n_units3': 83, 'n_units4': 121, 'optimizer': <class 'keras.src.optimizers.adam.Adam'>, 'learning_rate': 3.4834388975581265e-06, 'w0': 1.356038310206336, 'w1': 0.00569964802211707}.
# Restoring model weights from the end of the best epoch: 10.
# Epoch 40: early stopping
# [I 2023-11-27 08:59:32,910] Trial 3 finished with values: [0.8339511752128601, 0.0] and parameters: {'n_units1': 12, 'n_units2': 82, 'n_units3': 8, 'n_units4': 75, 'optimizer': <class 'keras.src.optimizers.adadelta.Adadelta'>, 'learning_rate': 0.01432113401490698, 'w0': 0.29499191529412633, 'w1': 0.0019538115177487945}.
# Restoring model weights from the end of the best epoch: 1.
# Epoch 31: early stopping
# [I 2023-11-27 08:59:50,792] Trial 4 finished with values: [0.1660488396883011, 1.0] and parameters: {'n_units1': 85, 'n_units2': 97, 'n_units3': 29, 'n_units4': 10, 'optimizer': <class 'keras.src.optimizers.adadelta.Adadelta'>, 'learning_rate': 0.07013217851373006, 'w0': 0.009437581839060412, 'w1': 1.042817635497103}.
# Restoring model weights from the end of the best epoch: 1.
# Epoch 31: early stopping
# [I 2023-11-27 09:00:13,234] Trial 5 finished with values: [0.17564326524734497, 0.966513454914093] and parameters: {'n_units1': 66, 'n_units2': 93, 'n_units3': 104, 'n_units4': 25, 'optimizer': <class 'keras.src.optimizers.adadelta.Adadelta'>, 'learning_rate': 0.00026504188311975423, 'w0': 0.010422548336828773, 'w1': 3.857265898914316}.
# Restoring model weights from the end of the best epoch: 3.
# Epoch 33: early stopping
# [I 2023-11-27 09:00:31,394] Trial 6 finished with values: [0.1660488396883011, 1.0] and parameters: {'n_units1': 98, 'n_units2': 96, 'n_units3': 41, 'n_units4': 59, 'optimizer': <class 'keras.src.optimizers.adam.Adam'>, 'learning_rate': 0.08285918021550093, 'w0': 0.004755225397898859, 'w1': 2.3772475267650592}.
# Restoring model weights from the end of the best epoch: 1.
# Epoch 31: early stopping
# [I 2023-11-27 09:00:50,644] Trial 7 finished with values: [0.8335150480270386, 0.0] and parameters: {'n_units1': 56, 'n_units2': 110, 'n_units3': 124, 'n_units4': 63, 'optimizer': <class 'keras.src.optimizers.adadelta.Adadelta'>, 'learning_rate': 0.01192472471962597, 'w0': 0.0014420288771163133, 'w1': 0.06343946274834239}.
# Restoring model weights from the end of the best epoch: 1.
# Epoch 31: early stopping
# [I 2023-11-27 09:01:13,972] Trial 8 finished with values: [0.19112516939640045, 0.9080761671066284] and parameters: {'n_units1': 60, 'n_units2': 109, 'n_units3': 50, 'n_units4': 50, 'optimizer': <class 'keras.src.optimizers.nadam.Nadam'>, 'learning_rate': 1.0222097819727137e-06, 'w0': 0.010174579576827675, 'w1': 2.5884945945534876}.
# Restoring model weights from the end of the best epoch: 121.
# Epoch 151: early stopping
# [I 2023-11-27 09:02:18,416] Trial 9 finished with values: [0.9771042466163635, 0.9152987599372864] and parameters: {'n_units1': 72, 'n_units2': 34, 'n_units3': 16, 'n_units4': 13, 'optimizer': <class 'keras.src.optimizers.rmsprop.RMSprop'>, 'learning_rate': 0.000375821142488931, 'w0': 0.5019737775357155, 'w1': 0.6318714392969568}.

# %%
best_trials = study.best_trials
best_params_list = [trial.params for trial in best_trials]
best_params_list
# Out:
# [{'n_units1': 85,
#   'n_units2': 97,
#   'n_units3': 29,
#   'n_units4': 10,
#   'optimizer': keras.src.optimizers.adadelta.Adadelta,
#   'learning_rate': 0.07013217851373006,
#   'w0': 0.009437581839060412,
#   'w1': 1.042817635497103},
#  {'n_units1': 66,
#   'n_units2': 93,
#   'n_units3': 104,
#   'n_units4': 25,
#   'optimizer': keras.src.optimizers.adadelta.Adadelta,
#   'learning_rate': 0.00026504188311975423,
#   'w0': 0.010422548336828773,
#   'w1': 3.857265898914316},
#  {'n_units1': 98,
#   'n_units2': 96,
#   'n_units3': 41,
#   'n_units4': 59,
#   'optimizer': keras.src.optimizers.adam.Adam,
#   'learning_rate': 0.08285918021550093,
#   'w0': 0.004755225397898859,
#   'w1': 2.3772475267650592},
#  {'n_units1': 72,
#   'n_units2': 34,
#   'n_units3': 16,
#   'n_units4': 13,
#   'optimizer': keras.src.optimizers.rmsprop.RMSprop,
#   'learning_rate': 0.000375821142488931,
#   'w0': 0.5019737775357155,
#   'w1': 0.6318714392969568}]

# %%
best_trials = study.best_trials
print("accuracy, recall")
for trial in best_trials:
    print(trial.values)
# Out:
# accuracy, recall
# [0.1660488396883011, 1.0]
# [0.17564326524734497, 0.966513454914093]
# [0.1660488396883011, 1.0]
# [0.9771042466163635, 0.9152987599372864]

# %%
selected_trial = int(input("select the trial:"))
if len(trial_metric) == 1:
    # This is for single value optimization
    best_params = study.best_params
else:
    # this is for multiple value optimization
    best_params = best_trials[selected_trial].params
best_params
# Out:
# select the trial:3
# {'n_units1': 72,
#  'n_units2': 34,
#  'n_units3': 16,
#  'n_units4': 13,
#  'optimizer': keras.src.optimizers.rmsprop.RMSprop,
#  'learning_rate': 0.000375821142488931,
#  'w0': 0.5019737775357155,
#  'w1': 0.6318714392969568}

# %%
optuna.visualization.plot_param_importances(study)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6a226317-53b0-49a3-9167-3c932a0ae0c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6a226317-53b0-49a3-9167-3c932a0ae0c3")) {                    Plotly.newPlot(                        "6a226317-53b0-49a3-9167-3c932a0ae0c3",                        [{"cliponaxis":false,"hovertemplate":["n_units3 (IntDistribution): 0.015927056811483722\u003cextra\u003e\u003c\u002fextra\u003e","optimizer (CategoricalDistribution): 0.01600543734246435\u003cextra\u003e\u003c\u002fextra\u003e","n_units1 (IntDistribution): 0.01601288869870694\u003cextra\u003e\u003c\u002fextra\u003e","learning_rate (FloatDistribution): 0.03325487962594015\u003cextra\u003e\u003c\u002fextra\u003e","w0 (FloatDistribution): 0.06495852416423997\u003cextra\u003e\u003c\u002fextra\u003e","n_units2 (IntDistribution): 0.08507260631013243\u003cextra\u003e\u003c\u002fextra\u003e","n_units4 (IntDistribution): 0.1743428895202793\u003cextra\u003e\u003c\u002fextra\u003e","w1 (FloatDistribution): 0.594425717526753\u003cextra\u003e\u003c\u002fextra\u003e"],"name":"Objective Value 0","orientation":"h","text":["0.02","0.02","0.02","0.03","0.06","0.09","0.17","0.59"],"textposition":"outside","x":[0.015927056811483722,0.01600543734246435,0.01601288869870694,0.03325487962594015,0.06495852416423997,0.08507260631013243,0.1743428895202793,0.594425717526753],"y":["n_units3","optimizer","n_units1","learning_rate","w0","n_units2","n_units4","w1"],"type":"bar"},{"cliponaxis":false,"hovertemplate":["learning_rate (FloatDistribution): 0.028442614415251574\u003cextra\u003e\u003c\u002fextra\u003e","n_units2 (IntDistribution): 0.029599812986809956\u003cextra\u003e\u003c\u002fextra\u003e","optimizer (CategoricalDistribution): 0.02985515052439174\u003cextra\u003e\u003c\u002fextra\u003e","w0 (FloatDistribution): 0.03712983744347043\u003cextra\u003e\u003c\u002fextra\u003e","n_units1 (IntDistribution): 0.09831289913604618\u003cextra\u003e\u003c\u002fextra\u003e","n_units3 (IntDistribution): 0.1775892424125171\u003cextra\u003e\u003c\u002fextra\u003e","w1 (FloatDistribution): 0.21924522273934538\u003cextra\u003e\u003c\u002fextra\u003e","n_units4 (IntDistribution): 0.3798252203421678\u003cextra\u003e\u003c\u002fextra\u003e"],"name":"Objective Value 1","orientation":"h","text":["0.03","0.03","0.03","0.04","0.10","0.18","0.22","0.38"],"textposition":"outside","x":[0.028442614415251574,0.029599812986809956,0.02985515052439174,0.03712983744347043,0.09831289913604618,0.1775892424125171,0.21924522273934538,0.3798252203421678],"y":["learning_rate","n_units2","optimizer","w0","n_units1","n_units3","w1","n_units4"],"type":"bar"}],                        {"title":{"text":"Hyperparameter Importances"},"xaxis":{"title":{"text":"Hyperparameter Importance"}},"yaxis":{"title":{"text":"Hyperparameter"}},"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""} ...

# %% [markdown]
# ### 6.4.1. Using Optuna Best Params

# %%
optuna = model_fit(params=best_params, X_train=X_train, y_train=y_train, X_val= X_val, y_val = y_val)
# Out:
# Epoch 1/1000
# 144/144 [==============================] - 3s 9ms/step - loss: 0.2762 - accuracy: 0.8263 - precision: 0.1635 - recall: 0.0112 - val_loss: 0.4246 - val_accuracy: 0.8338 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.2263 - accuracy: 0.8391 - precision: 0.8615 - recall: 0.0368 - val_loss: 0.3847 - val_accuracy: 0.8511 - val_precision: 0.8889 - val_recall: 0.1190
# Epoch 3/1000
# 144/144 [==============================] - 1s 7ms/step - loss: 0.2055 - accuracy: 0.8585 - precision: 0.7863 - recall: 0.2029 - val_loss: 0.3568 - val_accuracy: 0.8437 - val_precision: 0.5930 - val_recall: 0.1896
# Epoch 4/1000
# 144/144 [==============================] - 1s 7ms/step - loss: 0.1871 - accuracy: 0.8565 - precision: 0.6494 - recall: 0.2955 - val_loss: 0.3284 - val_accuracy: 0.8542 - val_precision: 0.6078 - val_recall: 0.3457
# Epoch 5/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.1663 - accuracy: 0.8717 - precision: 0.6787 - recall: 0.4314 - val_loss: 0.2889 - val_accuracy: 0.8746 - val_precision: 0.6774 - val_recall: 0.4684
# Epoch 6/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.1438 - accuracy: 0.8959 - precision: 0.7229 - recall: 0.6047 - val_loss: 0.2586 - val_accuracy: 0.8962 - val_precision: 0.6920 - val_recall: 0.6766
# Epoch 7/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.1257 - accuracy: 0.9147 - precision: 0.7618 - recall: 0.7078 - val_loss: 0.2296 - val_accuracy: 0.9129 - val_precision: 0.7270 - val_recall: 0.7621
# Epoch 8/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.1118 - accuracy: 0.9280 - precision: 0.7945 - recall: 0.7643 - val_loss: 0.2020 - val_accuracy: 0.9246 - val_precision: 0.7976 - val_recall: 0.7323
# Epoch 9/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.1013 - accuracy: 0.9373 - precision: 0.8123 - recall: 0.8096 - val_loss: 0.1845 - val_accuracy: 0.9376 - val_precision: 0.8088 - val_recall: 0.8178
# Epoch 10/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0942 - accuracy: 0.9446 - precision: 0.8306 - recall: 0.8372 - val_loss: 0.1764 - val_accuracy: 0.9407 - val_precision: 0.8014 - val_recall: 0.8550
# Epoch 11/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0893 - accuracy: 0.9482 - precision: 0.8372 - recall: 0.8542 - val_loss: 0.1788 - val_accuracy: 0.9401 - val_precision: 0.7848 - val_recall: 0.8810
# Epoch 12/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0852 - accuracy: 0.9512 - precision: 0.8448 - recall: 0.8647 - val_loss: 0.1570 - val_accuracy: 0.9518 - val_precision: 0.8524 - val_recall: 0.8587
# Epoch 13/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0828 - accuracy: 0.9537 - precision: 0.8510 - recall: 0.8739 - val_loss: 0.1549 - val_accuracy: 0.9531 - val_precision: 0.8784 - val_recall: 0.8327
# Epoch 14/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0802 - accuracy: 0.9554 - precision: 0.8548 - recall: 0.8812 - val_loss: 0.1584 - val_accuracy: 0.9500 - val_precision: 0.8197 - val_recall: 0.8959
# Epoch 15/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0786 - accuracy: 0.9572 - precision: 0.8608 - recall: 0.8851 - val_loss: 0.1429 - val_accuracy: 0.9605 - val_precision: 0.8839 - val_recall: 0.8773
# Epoch 16/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0765 - accuracy: 0.9586 - precision: 0.8675 - recall: 0.8858 - val_loss: 0.1436 - val_accuracy: 0.9586 - val_precision: 0.8797 - val_recall: 0.8699
# Epoch 17/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0756 - accuracy: 0.9585 - precision: 0.8679 - recall: 0.8844 - val_loss: 0.1413 - val_accuracy: 0.9599 - val_precision: 0.8669 - val_recall: 0.8959
# Epoch 18/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0744 - accuracy: 0.9604 - precision: 0.8742 - recall: 0.8897 - val_loss: 0.1426 - val_accuracy: 0.9549 - val_precision: 0.8427 - val_recall: 0.8959
# Epoch 19/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0731 - accuracy: 0.9616 - precision: 0.8765 - recall: 0.8949 - val_loss: 0.1383 - val_accuracy: 0.9605 - val_precision: 0.8674 - val_recall: 0.8996
# Epoch 20/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0718 - accuracy: 0.9628 - precision: 0.8813 - recall: 0.8969 - val_loss: 0.1398 - val_accuracy: 0.9549 - val_precision: 0.8356 - val_recall: 0.9071
# Epoch 21/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0711 - accuracy: 0.9608 - precision: 0.8716 - recall: 0.8956 - val_loss: 0.1326 - val_accuracy: 0.9605 - val_precision: 0.8596 - val_recall: 0.9108
# Epoch 22/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0697 - accuracy: 0.9639 - precision: 0.8835 - recall: 0.9015 - val_loss: 0.1362 - val_accuracy: 0.9580 - val_precision: 0.8478 - val_recall: 0.9108
# Epoch 23/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0692 - accuracy: 0.9633 - precision: 0.8836 - recall: 0.8969 - val_loss: 0.1268 - val_accuracy: 0.9648 - val_precision: 0.8841 - val_recall: 0.9071
# Epoch 24/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0681 - accuracy: 0.9643 - precision: 0.8893 - recall: 0.8969 - val_loss: 0.1278 - val_accuracy: 0.9648 - val_precision: 0.9141 - val_recall: 0.8699
# Epoch 25/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0674 - accuracy: 0.9662 - precision: 0.8988 - recall: 0.8976 - val_loss: 0.1285 - val_accuracy: 0.9636 - val_precision: 0.8723 - val_recall: 0.9145
# Epoch 26/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0668 - accuracy: 0.9663 - precision: 0.8973 - recall: 0.9002 - val_loss: 0.1248 - val_accuracy: 0.9642 - val_precision: 0.8754 - val_recall: 0.9145
# Epoch 27/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0661 - accuracy: 0.9672 - precision: 0.9014 - recall: 0.9009 - val_loss: 0.1211 - val_accuracy: 0.9691 - val_precision: 0.9163 - val_recall: 0.8959
# Epoch 28/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0652 - accuracy: 0.9679 - precision: 0.9051 - recall: 0.9015 - val_loss: 0.1199 - val_accuracy: 0.9679 - val_precision: 0.9189 - val_recall: 0.8848
# Epoch 29/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0646 - accuracy: 0.9688 - precision: 0.9104 - recall: 0.9009 - val_loss: 0.1292 - val_accuracy: 0.9636 - val_precision: 0.8723 - val_recall: 0.9145
# Epoch 30/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0642 - accuracy: 0.9673 - precision: 0.9047 - recall: 0.8976 - val_loss: 0.1199 - val_accuracy: 0.9685 - val_precision: 0.9067 - val_recall: 0.9033
# Epoch 31/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0636 - accuracy: 0.9677 - precision: 0.9044 - recall: 0.9009 - val_loss: 0.1254 - val_accuracy: 0.9648 - val_precision: 0.8786 - val_recall: 0.9145
# Epoch 32/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0630 - accuracy: 0.9695 - precision: 0.9119 - recall: 0.9035 - val_loss: 0.1187 - val_accuracy: 0.9691 - val_precision: 0.9163 - val_recall: 0.8959
# Epoch 33/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0625 - accuracy: 0.9694 - precision: 0.9129 - recall: 0.9015 - val_loss: 0.1165 - val_accuracy: 0.9697 - val_precision: 0.9264 - val_recall: 0.8885
# Epoch 34/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0623 - accuracy: 0.9695 - precision: 0.9141 - recall: 0.9009 - val_loss: 0.1144 - val_accuracy: 0.9697 - val_precision: 0.9167 - val_recall: 0.8996
# Epoch 35/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0620 - accuracy: 0.9697 - precision: 0.9158 - recall: 0.9002 - val_loss: 0.1137 - val_accuracy: 0.9704 - val_precision: 0.9139 - val_recall: 0.9071
# Epoch 36/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0612 - accuracy: 0.9711 - precision: 0.9210 - recall: 0.9035 - val_loss: 0.1142 - val_accuracy: 0.9710 - val_precision: 0.9302 - val_recall: 0.8922
# Epoch 37/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0611 - accuracy: 0.9707 - precision: 0.9202 - recall: 0.9015 - val_loss: 0.1147 - val_accuracy: 0.9697 - val_precision: 0.9104 - val_recall: 0.9071
# Epoch 38/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0604 - accuracy: 0.9719 - precision: 0.9231 - recall: 0.9061 - val_loss: 0.1137 - val_accuracy: 0.9697 - val_precision: 0.9297 - val_recall: 0.8848
# Epoch 39/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0602 - accuracy: 0.9710 - precision: 0.9232 - recall: 0.9002 - val_loss: 0.1125 - val_accuracy: 0.9710 - val_precision: 0.9237 - val_recall: 0.8996
# Epoch 40/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0598 - accuracy: 0.9723 - precision: 0.9273 - recall: 0.9041 - val_loss: 0.1134 - val_accuracy: 0.9704 - val_precision: 0.9170 - val_recall: 0.9033
# Epoch 41/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0593 - accuracy: 0.9719 - precision: 0.9271 - recall: 0.9015 - val_loss: 0.1115 - val_accuracy: 0.9710 - val_precision: 0.9237 - val_recall: 0.8996
# Epoch 42/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0590 - accuracy: 0.9721 - precision: 0.9272 - recall: 0.9028 - val_loss: 0.1114 - val_accuracy: 0.9704 - val_precision: 0.9234 - val_recall: 0.8959
# Epoch 43/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0588 - accuracy: 0.9726 - precision: 0.9303 - recall: 0.9028 - val_loss: 0.1169 - val_accuracy: 0.9691 - val_precision: 0.9011 - val_recall: 0.9145
# Epoch 44/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0584 - accuracy: 0.9727 - precision: 0.9321 - recall: 0.9015 - val_loss: 0.1112 - val_accuracy: 0.9716 - val_precision: 0.9305 - val_recall: 0.8959
# Epoch 45/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0580 - accuracy: 0.9723 - precision: 0.9296 - recall: 0.9015 - val_loss: 0.1106 - val_accuracy: 0.9697 - val_precision: 0.9167 - val_recall: 0.8996
# Epoch 46/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0575 - accuracy: 0.9731 - precision: 0.9322 - recall: 0.9035 - val_loss: 0.1146 - val_accuracy: 0.9710 - val_precision: 0.9205 - val_recall: 0.9033
# Epoch 47/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0576 - accuracy: 0.9734 - precision: 0.9341 - recall: 0.9035 - val_loss: 0.1109 - val_accuracy: 0.9722 - val_precision: 0.9275 - val_recall: 0.9033
# Epoch 48/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0569 - accuracy: 0.9732 - precision: 0.9341 - recall: 0.9022 - val_loss: 0.1087 - val_accuracy: 0.9716 - val_precision: 0.9339 - val_recall: 0.8922
# Epoch 49/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0563 - accuracy: 0.9739 - precision: 0.9338 - recall: 0.9074 - val_loss: 0.1118 - val_accuracy: 0.9691 - val_precision: 0.9101 - val_recall: 0.9033
# Epoch 50/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0561 - accuracy: 0.9738 - precision: 0.9349 - recall: 0.9054 - val_loss: 0.1096 - val_accuracy: 0.9722 - val_precision: 0.9409 - val_recall: 0.8885
# Epoch 51/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0560 - accuracy: 0.9737 - precision: 0.9355 - recall: 0.9041 - val_loss: 0.1151 - val_accuracy: 0.9685 - val_precision: 0.9037 - val_recall: 0.9071
# Epoch 52/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0556 - accuracy: 0.9739 - precision: 0.9367 - recall: 0.9041 - val_loss: 0.1109 - val_accuracy: 0.9716 - val_precision: 0.9272 - val_recall: 0.8996
# Epoch 53/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0555 - accuracy: 0.9745 - precision: 0.9387 - recall: 0.9054 - val_loss: 0.1096 - val_accuracy: 0.9679 - val_precision: 0.9094 - val_recall: 0.8959
# Epoch 54/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0549 - accuracy: 0.9747 - precision: 0.9382 - recall: 0.9074 - val_loss: 0.1105 - val_accuracy: 0.9691 - val_precision: 0.9101 - val_recall: 0.9033
# Epoch 55/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0549 - accuracy: 0.9753 - precision: 0.9414 - recall: 0.9074 - val_loss: 0.1086 - val_accuracy: 0.9691 - val_precision: 0.9163 - val_recall: 0.8959
# Epoch 56/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0544 - accuracy: 0.9743 - precision: 0.9381 - recall: 0.9048 - val_loss: 0.1190 - val_accuracy: 0.9685 - val_precision: 0.8921 - val_recall: 0.9219
# Epoch 57/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0542 - accuracy: 0.9742 - precision: 0.9368 - recall: 0.9054 - val_loss: 0.1110 - val_accuracy: 0.9704 - val_precision: 0.9170 - val_recall: 0.9033
# Epoch 58/1000
# 144/144 [==============================] - 1s 3ms/step - loss: 0.0541 - accuracy: 0.9750 - precision: 0.9401 - recall: 0.9074 - val_loss: 0.1093 - val_accuracy: 0.9722 - val_precision: 0.9409 - val_recall: 0.8885
# Epoch 59/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0537 - accuracy: 0.9751 - precision: 0.9432 - recall: 0.9048 - val_loss: 0.1116 - val_accuracy: 0.9691 - val_precision: 0.9071 - val_recall: 0.9071
# Epoch 60/1000
# 144/144 [==============================] - 1s 3ms/step - loss: 0.0535 - accuracy: 0.9743 - precision: 0.9381 - recall: 0.9048 - val_loss: 0.1081 - val_accuracy: 0.9710 - val_precision: 0.9237 - val_recall: 0.8996
# Epoch 61/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0531 - accuracy: 0.9742 - precision: 0.9386 - recall: 0.9035 - val_loss: 0.1072 - val_accuracy: 0.9697 - val_precision: 0.9198 - val_recall: 0.8959
# Epoch 62/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0530 - accuracy: 0.9756 - precision: 0.9440 - recall: 0.9068 - val_loss: 0.1178 - val_accuracy: 0.9673 - val_precision: 0.8942 - val_recall: 0.9108
# Epoch 63/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0524 - accuracy: 0.9759 - precision: 0.9411 - recall: 0.9120 - val_loss: 0.1099 - val_accuracy: 0.9710 - val_precision: 0.9205 - val_recall: 0.9033
# Epoch 64/1000
# 144/144 [==============================] - 1s 3ms/step - loss: 0.0522 - accuracy: 0.9756 - precision: 0.9427 - recall: 0.9081 - val_loss: 0.1149 - val_accuracy: 0.9704 - val_precision: 0.9077 - val_recall: 0.9145
# Epoch 65/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0520 - accuracy: 0.9749 - precision: 0.9413 - recall: 0.9054 - val_loss: 0.1060 - val_accuracy: 0.9710 - val_precision: 0.9269 - val_recall: 0.8959
# Epoch 66/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0516 - accuracy: 0.9762 - precision: 0.9472 - recall: 0.9074 - val_loss: 0.1093 - val_accuracy: 0.9679 - val_precision: 0.9094 - val_recall: 0.8959
# Epoch 67/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0517 - accuracy: 0.9750 - precision: 0.9425 - recall: 0.9048 - val_loss: 0.1072 - val_accuracy: 0.9710 - val_precision: 0.9269 - val_recall: 0.8959
# Epoch 68/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0515 - accuracy: 0.9759 - precision: 0.9447 - recall: 0.9081 - val_loss: 0.1104 - val_accuracy: 0.9679 - val_precision: 0.9064 - val_recall: 0.8996
# Epoch 69/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0512 - accuracy: 0.9766 - precision: 0.9473 - recall: 0.9094 - val_loss: 0.1152 - val_accuracy: 0.9660 - val_precision: 0.8905 - val_recall: 0.9071
# Epoch 70/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0510 - accuracy: 0.9755 - precision: 0.9415 - recall: 0.9087 - val_loss: 0.1094 - val_accuracy: 0.9691 - val_precision: 0.9132 - val_recall: 0.8996
# Epoch 71/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0506 - accuracy: 0.9757 - precision: 0.9440 - recall: 0.9074 - val_loss: 0.1090 - val_accuracy: 0.9722 - val_precision: 0.9308 - val_recall: 0.8996
# Epoch 72/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0502 - accuracy: 0.9768 - precision: 0.9492 - recall: 0.9087 - val_loss: 0.1251 - val_accuracy: 0.9673 - val_precision: 0.8857 - val_recall: 0.9219
# Epoch 73/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0504 - accuracy: 0.9763 - precision: 0.9436 - recall: 0.9120 - val_loss: 0.1067 - val_accuracy: 0.9734 - val_precision: 0.9449 - val_recall: 0.8922
# Epoch 74/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0503 - accuracy: 0.9761 - precision: 0.9460 - recall: 0.9081 - val_loss: 0.1094 - val_accuracy: 0.9679 - val_precision: 0.9033 - val_recall: 0.9033
# Epoch 75/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0496 - accuracy: 0.9759 - precision: 0.9447 - recall: 0.9081 - val_loss: 0.1069 - val_accuracy: 0.9722 - val_precision: 0.9341 - val_recall: 0.8959
# Epoch 76/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0497 - accuracy: 0.9759 - precision: 0.9459 - recall: 0.9068 - val_loss: 0.1160 - val_accuracy: 0.9666 - val_precision: 0.8909 - val_recall: 0.9108
# Epoch 77/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0496 - accuracy: 0.9760 - precision: 0.9423 - recall: 0.9114 - val_loss: 0.1098 - val_accuracy: 0.9673 - val_precision: 0.9000 - val_recall: 0.9033
# Epoch 78/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0490 - accuracy: 0.9766 - precision: 0.9479 - recall: 0.9087 - val_loss: 0.1097 - val_accuracy: 0.9722 - val_precision: 0.9409 - val_recall: 0.8885
# Epoch 79/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0492 - accuracy: 0.9762 - precision: 0.9454 - recall: 0.9094 - val_loss: 0.1071 - val_accuracy: 0.9710 - val_precision: 0.9237 - val_recall: 0.8996
# Epoch 80/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0488 - accuracy: 0.9771 - precision: 0.9500 - recall: 0.9100 - val_loss: 0.1091 - val_accuracy: 0.9691 - val_precision: 0.9101 - val_recall: 0.9033
# Epoch 81/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0488 - accuracy: 0.9760 - precision: 0.9441 - recall: 0.9094 - val_loss: 0.1248 - val_accuracy: 0.9636 - val_precision: 0.8777 - val_recall: 0.9071
# Epoch 82/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0485 - accuracy: 0.9775 - precision: 0.9513 - recall: 0.9114 - val_loss: 0.1080 - val_accuracy: 0.9685 - val_precision: 0.9067 - val_recall: 0.9033
# Epoch 83/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0482 - accuracy: 0.9774 - precision: 0.9519 - recall: 0.9100 - val_loss: 0.1057 - val_accuracy: 0.9704 - val_precision: 0.9234 - val_recall: 0.8959
# Epoch 84/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0481 - accuracy: 0.9773 - precision: 0.9500 - recall: 0.9114 - val_loss: 0.1060 - val_accuracy: 0.9704 - val_precision: 0.9234 - val_recall: 0.8959
# Epoch 85/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0479 - accuracy: 0.9779 - precision: 0.9539 - recall: 0.9107 - val_loss: 0.1071 - val_accuracy: 0.9704 - val_precision: 0.9170 - val_recall: 0.9033
# Epoch 86/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0478 - accuracy: 0.9776 - precision: 0.9501 - recall: 0.9133 - val_loss: 0.1083 - val_accuracy: 0.9685 - val_precision: 0.9098 - val_recall: 0.8996
# Epoch 87/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0474 - accuracy: 0.9778 - precision: 0.9520 - recall: 0.9120 - val_loss: 0.1108 - val_accuracy: 0.9673 - val_precision: 0.9000 - val_recall: 0.9033
# Epoch 88/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0473 - accuracy: 0.9779 - precision: 0.9521 - recall: 0.9127 - val_loss: 0.1106 - val_accuracy: 0.9697 - val_precision: 0.9135 - val_recall: 0.9033
# Epoch 89/1000
# 144/144 [==============================] - 0s 3ms/step - loss: 0.0473 - accuracy: 0.9780 - precision: 0.9521 - recall: 0.9133 - val_loss: 0.1071 - val_accuracy: 0.9704 - val_precision: 0.9170 - val_recall: 0.9033
# Epoch 90/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0469 - accuracy: 0.9781 - precision: 0.9521 - recall: 0.9140 - val_loss: 0.1077 - val_accuracy: 0.9704 - val_precision: 0.9234 - val_recall: 0.8959
# Epoch 91/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0471 - accuracy: 0.9772 - precision: 0.9512 - recall: 0.9094 - val_loss: 0.1115 - val_accuracy: 0.9679 - val_precision: 0.9033 - val_recall: 0.9033
# Epoch 92/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0466 - accuracy: 0.9782 - precision: 0.9515 - recall: 0.9153 - val_loss: 0.1122 - val_accuracy: 0.9666 - val_precision: 0.8967 - val_recall: 0.9033
# Epoch 93/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0468 - accuracy: 0.9782 - precision: 0.9553 - recall: 0.9114 - val_loss: 0.1106 - val_accuracy: 0.9685 - val_precision: 0.9067 - val_recall: 0.9033
# Epoch 94/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0460 - accuracy: 0.9782 - precision: 0.9528 - recall: 0.9140 - val_loss: 0.1164 - val_accuracy: 0.9679 - val_precision: 0.9004 - val_recall: 0.9071
# Epoch 95/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0464 - accuracy: 0.9787 - precision: 0.9554 - recall: 0.9146 - val_loss: 0.1169 - val_accuracy: 0.9673 - val_precision: 0.8971 - val_recall: 0.9071
# Epoch 96/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0460 - accuracy: 0.9781 - precision: 0.9546 - recall: 0.9114 - val_loss: 0.1183 - val_accuracy: 0.9666 - val_precision: 0.8909 - val_recall: 0.9108
# Epoch 97/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0461 - accuracy: 0.9780 - precision: 0.9515 - recall: 0.9140 - val_loss: 0.1066 - val_accuracy: 0.9710 - val_precision: 0.9237 - val_recall: 0.8996
# Epoch 98/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0458 - accuracy: 0.9785 - precision: 0.9566 - recall: 0.9120 - val_loss: 0.1075 - val_accuracy: 0.9716 - val_precision: 0.9373 - val_recall: 0.8885
# Epoch 99/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0457 - accuracy: 0.9783 - precision: 0.9547 - recall: 0.9127 - val_loss: 0.1065 - val_accuracy: 0.9728 - val_precision: 0.9412 - val_recall: 0.8922
# Epoch 100/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0452 - accuracy: 0.9781 - precision: 0.9527 - recall: 0.9133 - val_loss: 0.1072 - val_accuracy: 0.9728 - val_precision: 0.9310 - val_recall: 0.9033
# Epoch 101/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0454 - accuracy: 0.9781 - precision: 0.9540 - recall: 0.9120 - val_loss: 0.1105 - val_accuracy: 0.9697 - val_precision: 0.9135 - val_recall: 0.9033
# Epoch 102/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0451 - accuracy: 0.9783 - precision: 0.9553 - recall: 0.9120 - val_loss: 0.1094 - val_accuracy: 0.9716 - val_precision: 0.9272 - val_recall: 0.8996
# Epoch 103/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0449 - accuracy: 0.9791 - precision: 0.9586 - recall: 0.9133 - val_loss: 0.1087 - val_accuracy: 0.9728 - val_precision: 0.9377 - val_recall: 0.8959
# Epoch 104/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0447 - accuracy: 0.9791 - precision: 0.9568 - recall: 0.9153 - val_loss: 0.1146 - val_accuracy: 0.9704 - val_precision: 0.9170 - val_recall: 0.9033
# Epoch 105/1000
# 144/144 [==============================] - 1s 6ms/step - loss: 0.0448 - accuracy: 0.9779 - precision: 0.9539 - recall: 0.9107 - val_loss: 0.1102 - val_accuracy: 0.9734 - val_precision: 0.9449 - val_recall: 0.8922
# Epoch 106/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0447 - accuracy: 0.9785 - precision: 0.9547 - recall: 0.9140 - val_loss: 0.1154 - val_accuracy: 0.9673 - val_precision: 0.8971 - val_recall: 0.9071
# Epoch 107/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0441 - accuracy: 0.9788 - precision: 0.9567 - recall: 0.9140 - val_loss: 0.1118 - val_accuracy: 0.9716 - val_precision: 0.9514 - val_recall: 0.8736
# Epoch 108/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0443 - accuracy: 0.9787 - precision: 0.9548 - recall: 0.9153 - val_loss: 0.1185 - val_accuracy: 0.9673 - val_precision: 0.9000 - val_recall: 0.9033
# Epoch 109/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0439 - accuracy: 0.9788 - precision: 0.9573 - recall: 0.9133 - val_loss: 0.1080 - val_accuracy: 0.9710 - val_precision: 0.9302 - val_recall: 0.8922
# Epoch 110/1000
# 144/144 [==============================] - 1s 5ms/step - loss: 0.0442 - accuracy: 0.9795 - precision: 0.9600 - recall: 0.9146 - val_loss: 0.1142 - val_accuracy: 0.9704 - val_precision: 0.9202 - val_recall: 0.8996
# Epoch 111/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0437 - accuracy: 0.9791 - precision: 0.9549 - recall: 0.9173 - val_loss: 0.1087 - val_accuracy: 0.9722 - val_precision: 0.9375 - val_recall: 0.8922
# Epoch 112/1000
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0439 - accuracy: 0.9794 - precision: 0.9568 - recall: 0.9173 - val_loss: 0.1180 - val_accuracy: 0.9685 - val_precision: 0.9098 - val_recall: 0.8996
# Epoch 113/1000
# 134/144 [==========================>...] - ETA: 0s - loss: 0.0425 - accuracy: 0.9806 - precision: 0.9599 - recall: 0.9222Restoring model weights from the end of the best epoch: 83.
# 144/144 [==============================] - 1s 4ms/step - loss: 0.0435 - accuracy: 0.9800 - precision: 0.9583 - recall: 0.9199 - val_loss: 0.1181 - val_accuracy: 0.9679 - val_precision: 0.9064 - val_recall: 0.8996
# Epoch 113: early stopping

# %%
optuna.summary()
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_102 (Dense)           (None, 72)                1296
#
#  dense_103 (Dense)           (None, 34)                2482
#
#  dense_104 (Dense)           (None, 16)                560
#
#  dense_105 (Dense)           (None, 13)                221
#
#  dense_106 (Dense)           (None, 1)                 14
#
# =================================================================
# Total params: 4573 (17.86 KB)
# Trainable params: 4573 (17.86 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
optuna.save('DL_optuna.h5')

# %%
optuna_loss_df = pd.DataFrame(optuna.history.history)
optuna_loss_df.tail()
# Out:
#      loss  accuracy  precision  recall  val_loss  val_accuracy  val_precision  \
# 108 0.044     0.979      0.957   0.913     0.108         0.971          0.930
# 109 0.044     0.980      0.960   0.915     0.114         0.970          0.920
# 110 0.044     0.979      0.955   0.917     0.109         0.972          0.938
# 111 0.044     0.979      0.957   0.917     0.118         0.968          0.910
# 112 0.044     0.980      0.958   0.920     0.118         0.968          0.906
#
#      val_recall
# 108       0.892
# 109       0.900
# 110       0.892
# 111       0.900
# 112       0.900

# %%
# optuna_loss_df.plot()
optuna_loss_df.plot(subplots=[['loss','val_loss'],
                            ['accuracy','val_accuracy'],
                            ['precision', 'val_precision'],
                            ['recall', 'val_recall']],
                            layout=(2,2),
                            figsize=(12,6));

# %%
loss, accuracy, precision, recall = optuna.evaluate(X_test, y_test, verbose=0)
print("optuna test loss: ", loss)
print("optuna test accuracy: ", accuracy)
print("optuna test precision ", precision)
print("optuna test recall: ", recall)
# Out:
# optuna test loss:  0.08173955976963043
# optuna test accuracy:  0.9783333539962769
# optuna test precision  0.9481865167617798
# optuna test recall:  0.9195979833602905

# %%
loss, accuracy, precision, recall = optuna.evaluate(X_train, y_train, verbose=0)
print("optuna train loss: ", loss)
print("optuna train accuracy: ", accuracy)
print("optuna train precision ", precision)
print("optuna train recall: ", recall)
# Out:
# optuna train loss:  0.07933439314365387
# optuna train accuracy:  0.9788486957550049
# optuna train precision  0.9604989886283875
# optuna train recall:  0.9100459814071655

# %%
con_matrix(X_train, X_test, y_train, y_test, optuna, 'Optuna')
# Out:
# 38/38 [==============================] - 0s 2ms/step
# Optuna - Test Confusion Matrix
# **************************************************
# [[991  10]
#  [ 16 183]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      1001
#          1.0       0.95      0.92      0.93       199
#
#     accuracy                           0.98      1200
#    macro avg       0.97      0.95      0.96      1200
# weighted avg       0.98      0.98      0.98      1200
#
#
# 287/287 [==============================] - 1s 3ms/step
# Optuna - Train Confusion Matrix
# **************************************************
# [[7592   57]
#  [ 137 1386]]
#               precision    recall  f1-score   support
#
#          0.0       0.98      0.99      0.99      7649
#          1.0       0.96      0.91      0.93      1523
#
#     accuracy                           0.98      9172
#    macro avg       0.97      0.95      0.96      9172
# weighted avg       0.98      0.98      0.98      9172

# %%
y_pred_proba4 = optuna.predict(X_test)
y_pred_proba_train4 = optuna.predict(X_train)

y_pred4 =  (optuna.predict(X_test) > .5).astype("int32")
y_pred_train4 =  (optuna.predict(X_train) > .5).astype("int32")

print("Average Test Precision Score:  ", average_precision_score(y_test, y_pred_proba4))
print("Average Train Precision Score: ", average_precision_score(y_train, y_pred_proba_train4))
print("F1 Test Precision Score: ", f1_score(y_test, y_pred4))
print("F1 Train Precision Score:",f1_score(y_train, y_pred_train4))
print("Recall Test Precision Score: ", recall_score(y_test, y_pred4))
print("Recall Train Precision Score:",recall_score(y_train, y_pred_train4))
# Out:
# 38/38 [==============================] - 0s 3ms/step
# 287/287 [==============================] - 1s 3ms/step
# 38/38 [==============================] - 0s 3ms/step
# 287/287 [==============================] - 1s 3ms/step
# Average Test Precision Score:   0.9654377770942394
# Average Train Precision Score:  0.9649199645746965
# F1 Test Precision Score:  0.9336734693877552
# F1 Train Precision Score: 0.9345920431557654
# Recall Test Precision Score:  0.9195979899497487
# Recall Train Precision Score: 0.9100459619172685

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# ROC curve for the test data
RocCurveDisplay.from_predictions(y_test, y_pred_proba4, ax=axes[0])
axes[0].set_title('Test ROC Curve')

# ROC curve for the train data
RocCurveDisplay.from_predictions(y_train, y_pred_proba_train4, ax=axes[1])
axes[1].set_title('Train ROC Curve')
plt.tight_layout();

# %%
plt.figure(figsize=(12, 6))

# Precision-recall curve for the test data
precisions_test, recalls_test, thresholds_test = precision_recall_curve(y_test, y_pred_proba4)
plt.subplot(1, 2, 1)  # Arrange two plots side by side, this is the first plot
plt.plot(recalls_test, precisions_test, label='ANN')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (Test)')

# Precision-recall curve for the train data
precisions_train, recalls_train, thresholds_train = precision_recall_curve(y_train, y_pred_proba_train4)
plt.subplot(1, 2, 2)  # Arrange two plots side by side, this is the second plot
plt.plot(recalls_train, precisions_train, label='ANN')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (Train)')

plt.tight_layout();

# %% [markdown]
# # ✨ PART - 7 Compare Models Performances ✨
# - Compare model performances according to metrics you choose for the problem.

# %%
vanilla = load_model('DL_vanilla.h5')
vanilla_LR_0_003 = load_model('DL_vanilla_LR_0_003.h5')
vanilla_LR_0_003_ES = load_model('DL_vanilla_LR_0_003_ES.h5')
optuna = load_model('DL_optuna.h5')

models = [vanilla, vanilla_LR_0_003, vanilla_LR_0_003_ES, optuna]
model_names = ['ANN Vanilla', 'ANN Vanilla LR 0.003', 'ANN Vanilla LR 0.003 ES','ANN Optuna' ]


compare = pd.DataFrame(columns=['Model', 'AUC', 'Accuracy', 'Precision','Recall'])



for model, model_name in zip(models, model_names):
    # y_pred = model.predict(X_test)
    y_pred_proba = model.predict(X_test, verbose=0)
    y_pred =(y_pred_proba > 0.5).astype("int32")

    auc_score = roc_auc_score(y_test, y_pred_proba)

    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    ap = average_precision_score(y_test, y_pred_proba)

    compare = compare.append({'Model': model_name,
                              'AUC': auc_score,
                              'Accuracy': accuracy,
                              'Precision': precision,
                              'Recall': recall,
                              'F1 Score': f1,
                              'AP': ap}, ignore_index=True)

compare
# Out:
#                      Model   AUC  Accuracy  Precision  Recall  F1 Score    AP
# 0              ANN Vanilla 0.968     0.962      0.856   0.925     0.889 0.911
# 1     ANN Vanilla LR 0.003 0.971     0.961      0.858   0.915     0.886 0.933
# 2  ANN Vanilla LR 0.003 ES 0.971     0.961      0.855   0.920     0.886 0.938
# 3               ANN Optuna 0.983     0.978      0.948   0.920     0.934 0.965

# %%
plt.figure(figsize=(10,10))

plt.subplot(611)
compare = compare.sort_values(by="AUC", ascending=False)
ax=sns.barplot(x="AUC", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(612)
compare = compare.sort_values(by="Accuracy", ascending=False)
ax=sns.barplot(x="Accuracy", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(613)
compare = compare.sort_values(by="Precision", ascending=False)
ax=sns.barplot(x="Precision", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(614)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(615)
compare = compare.sort_values(by="F1 Score", ascending=False)
ax=sns.barplot(x="F1 Score", y="Model", data=compare, palette="Blues_d" )
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(616)
compare = compare.sort_values(by="AP", ascending=False)
ax=sns.barplot(x="AP", y="Model", data=compare, palette="Blues_d" )
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.tight_layout()
plt.show();

# %%
X_ = df.drop(columns= ["left"])
y_ = df.left

X_train_, X_test_, y_train_, y_test_ = train_test_split(X_, y_, test_size=0.2, random_state=seed, stratify = y_)

# %%
with open('logisticregression.pkl', 'rb') as file:
    logisticregression  = pickle.load(file)

with open('randomforest.pkl', 'rb') as file:
    randomforest  = pickle.load(file)

with open('gradientboost.pkl', 'rb') as file:
    gradientboost  = pickle.load(file)

with open('xgboost.pkl', 'rb') as file:
    xgboost  = pickle.load(file)

# %%
models = [logisticregression, randomforest, gradientboost, xgboost]
model_names = ["Logistic Regression", "Random Forest", "Gradient Boost" ,"XGBoost"]

# compare = pd.DataFrame(columns=['Model', 'AUC', 'Accuracy', 'Precision','Recall'])


for model, model_name in zip(models, model_names):
  y_pred_proba = model.predict(X_test_)

  y_pred = ( y_pred_proba > .5).astype("int32")


  # y_pred = model.predict(X_test_)
  auc_score = roc_auc_score(y_test_, y_pred_proba)

  accuracy = accuracy_score(y_test_, y_pred)
  precision = precision_score(y_test_, y_pred)
  recall = recall_score(y_test_, y_pred)
  f1 = f1_score(y_test_, y_pred)

  ap = average_precision_score(y_test_, y_pred_proba)


  compare = compare.append({'Model': model_name,
                              'AUC': auc_score,
                              'Accuracy': accuracy,
                              'Precision': precision,
                              'Recall': recall,
                              'F1 Score': f1,
                              'AP': ap}, ignore_index=True)

compare
# Out:
#                      Model   AUC  Accuracy  Precision  Recall  F1 Score    AP
# 0               ANN Optuna 0.983     0.978      0.948   0.920     0.934 0.965
# 1  ANN Vanilla LR 0.003 ES 0.971     0.961      0.855   0.920     0.886 0.938
# 2     ANN Vanilla LR 0.003 0.971     0.961      0.858   0.915     0.886 0.933
# 3              ANN Vanilla 0.968     0.962      0.856   0.925     0.889 0.911
# 4      Logistic Regression 0.806     0.782      0.422   0.842     0.562 0.381
# 5            Random Forest 0.961     0.985      0.981   0.925     0.952 0.920
# 6           Gradient Boost 0.962     0.986      0.987   0.927     0.956 0.927
# 7                  XGBoost 0.960     0.980      0.951   0.930     0.940 0.896

# %%
plt.figure(figsize=(10,10))

plt.subplot(611)
compare = compare.sort_values(by="AUC", ascending=False)
ax=sns.barplot(x="AUC", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(612)
compare = compare.sort_values(by="Accuracy", ascending=False)
ax=sns.barplot(x="Accuracy", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(613)
compare = compare.sort_values(by="Precision", ascending=False)
ax=sns.barplot(x="Precision", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(614)
compare = compare.sort_values(by="Recall", ascending=False)
ax=sns.barplot(x="Recall", y="Model", data=compare, palette="Blues_d")
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(615)
compare = compare.sort_values(by="F1 Score", ascending=False)
ax=sns.barplot(x="F1 Score", y="Model", data=compare, palette="Blues_d" )
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.subplot(616)
compare = compare.sort_values(by="AP", ascending=False)
ax=sns.barplot(x="AP", y="Model", data=compare, palette="Blues_d" )
ax.bar_label(ax.containers[0],fmt="%.3f")

plt.tight_layout()
plt.show();

# %% [markdown]
# # ✨ PART - 8 Final Model Deployment ✨

# %%
 # retrain  with extended train dataset

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    stratify=y,
                                                    test_size=0.1,
                                                    random_state=seed)

# %%
print("X_train shape", X_train.shape)
print("X_test shape",X_test.shape)
# Out:
# X_train shape (10791, 9)
# X_test shape (1200, 9)

# %%
pickle.dump(ordinal, open("ordinal_employee_churn", "wb"))
ordinal = pickle.load(open("ordinal_employee_churn", "rb"))

X_train['salary'] = ordinal.fit_transform(X_train[['salary']])
X_test ['salary'] = ordinal.transform(X_test[['salary']])

# %%
pickle.dump(col_transformer, open("scaler_employee_churn", "wb"))
col_transformer = pickle.load(open("scaler_employee_churn", "rb"))

# using col_transformer for one hot encoding to train_datas
transformed_data = pd.DataFrame(col_transformer.fit_transform(X_train))
transformed_data.columns = col_transformer.get_feature_names_out(input_features=X_train.columns )
transformed_data.columns =  [col.split('__')[-1] for col in transformed_data.columns]
X_train = transformed_data
X_train.head()
# Out:
#    departments_RandD  departments_accounting  departments_hr  \
# 0              0.000                   0.000           0.000
# 1              0.000                   0.000           0.000
# 2              0.000                   0.000           0.000
# 3              0.000                   0.000           0.000
# 4              0.000                   0.000           0.000
#
#    departments_management  departments_marketing  departments_product_mng  \
# 0                   0.000                  0.000                    0.000
# 1                   0.000                  0.000                    0.000
# 2                   0.000                  0.000                    0.000
# 3                   0.000                  0.000                    0.000
# 4                   1.000                  0.000                    0.000
#
#    departments_sales  departments_support  departments_technical  \
# 0              1.000                0.000                  0.000
# 1              0.000                0.000                  1.000
# 2              1.000                0.000                  0.000
# 3              0.000                0.000                  0.000
# 4              0.000                0.000                  0.000
#
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0               0.945            0.188           0.600                 0.551
# 1               0.901            0.625           0.200                 0.472
# 2               0.363            0.828           0.800                 0.430
# 3               0.582            0.438           0.400                 0.416
# 4               0.593            0.906           0.200                 0.355
#
#    time_spend_company  work_accident  promotion_last_5years  salary
# 0               0.500          1.000                  1.000   0.500
# 1               0.125          0.000                  0.000   0.500
# 2               0.375          1.000                  0.000   0.000
# 3               0.000          0.000                  0.000   0.500
# 4               0.125          0.000                  0.000   0.500

# %%
# using col_transformer for one hot encoding to test_dataset
transformed_data = pd.DataFrame(col_transformer.transform(X_test))
transformed_data.columns = col_transformer.get_feature_names_out(input_features=X_test.columns )
transformed_data.columns =  [col.split('__')[-1] for col in transformed_data.columns]
X_test = transformed_data
X_test.head()
# Out:
#    departments_RandD  departments_accounting  departments_hr  \
# 0              0.000                   0.000           0.000
# 1              0.000                   1.000           0.000
# 2              0.000                   0.000           0.000
# 3              0.000                   0.000           0.000
# 4              0.000                   0.000           0.000
#
#    departments_management  departments_marketing  departments_product_mng  \
# 0                   0.000                  0.000                    0.000
# 1                   0.000                  0.000                    0.000
# 2                   0.000                  0.000                    0.000
# 3                   0.000                  0.000                    1.000
# 4                   0.000                  0.000                    0.000
#
#    departments_sales  departments_support  departments_technical  \
# 0              0.000                1.000                  0.000
# 1              0.000                0.000                  0.000
# 2              0.000                0.000                  1.000
# 3              0.000                0.000                  0.000
# 4              1.000                0.000                  0.000
#
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0               0.560            0.422           0.600                 0.799
# 1               0.011            0.750           0.600                 0.967
# 2               0.901            0.109           0.400                 0.098
# 3               0.473            0.688           0.200                 0.729
# 4               0.747            0.094           0.400                 0.009
#
#    time_spend_company  work_accident  promotion_last_5years  salary
# 0               0.125          0.000                  0.000   0.000
# 1               0.375          0.000                  0.000   0.500
# 2               0.375          1.000                  0.000   0.500
# 3               0.250          0.000                  0.000   0.000
# 4               0.000          0.000                  0.000   0.000

# %%
print("X_train shape", X_train.shape)
print("X_test shape",X_test.shape)
# Out:
# X_train shape (10791, 17)
# X_test shape (1200, 17)

# %% [markdown]
# ## 8.1. Final Model

# %%
best_params
# Out:
# {'n_units1': 72,
#  'n_units2': 34,
#  'n_units3': 16,
#  'n_units4': 13,
#  'optimizer': keras.src.optimizers.rmsprop.RMSprop,
#  'learning_rate': 0.000375821142488931,
#  'w0': 0.5019737775357155,
#  'w1': 0.6318714392969568}

# %%
unit1, unit2, unit3, unit4, optimizer, lr, w0, w1 = best_params.values()
model = Sequential()
model.add(Dense(unit1, activation="relu"))
model.add(Dense(unit2, activation="relu"))
model.add(Dense(unit3, activation="relu"))
model.add(Dense(unit4, activation="relu"))
model.add(Dense(1, activation="sigmoid"))
opt = optimizer(learning_rate=lr)
model.compile(optimizer=opt, loss="binary_crossentropy", metrics=["accuracy", "Precision", "Recall"])

# %%
model.fit(x=X_train,
          y=y_train,
          validation_data=(X_test, y_test),
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          callbacks=[early_stop],
          class_weight = {0: w0, 1: w1} )
# Out:
# Epoch 1/1000
# 169/169 [==============================] - 2s 6ms/step - loss: 0.2749 - accuracy: 0.8339 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.4072 - val_accuracy: 0.8342 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.2250 - accuracy: 0.8339 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.3575 - val_accuracy: 0.8342 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.2036 - accuracy: 0.8340 - precision: 0.6000 - recall: 0.0017 - val_loss: 0.3176 - val_accuracy: 0.8350 - val_precision: 0.6000 - val_recall: 0.0151
# Epoch 4/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.1854 - accuracy: 0.8450 - precision: 0.6374 - recall: 0.1540 - val_loss: 0.2926 - val_accuracy: 0.8667 - val_precision: 0.6726 - val_recall: 0.3819
# Epoch 5/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.1678 - accuracy: 0.8673 - precision: 0.6562 - recall: 0.4219 - val_loss: 0.2596 - val_accuracy: 0.8725 - val_precision: 0.6885 - val_recall: 0.4221
# Epoch 6/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.1518 - accuracy: 0.8834 - precision: 0.6741 - recall: 0.5770 - val_loss: 0.2351 - val_accuracy: 0.9067 - val_precision: 0.7164 - val_recall: 0.7236
# Epoch 7/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.1375 - accuracy: 0.9052 - precision: 0.7178 - recall: 0.7070 - val_loss: 0.2107 - val_accuracy: 0.9225 - val_precision: 0.7944 - val_recall: 0.7186
# Epoch 8/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.1241 - accuracy: 0.9222 - precision: 0.7621 - recall: 0.7723 - val_loss: 0.1861 - val_accuracy: 0.9325 - val_precision: 0.7980 - val_recall: 0.7940
# Epoch 9/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.1106 - accuracy: 0.9352 - precision: 0.7930 - recall: 0.8253 - val_loss: 0.1656 - val_accuracy: 0.9458 - val_precision: 0.8317 - val_recall: 0.8442
# Epoch 10/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0997 - accuracy: 0.9425 - precision: 0.8146 - recall: 0.8460 - val_loss: 0.1502 - val_accuracy: 0.9508 - val_precision: 0.8333 - val_recall: 0.8794
# Epoch 11/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0924 - accuracy: 0.9488 - precision: 0.8319 - recall: 0.8672 - val_loss: 0.1422 - val_accuracy: 0.9525 - val_precision: 0.8287 - val_recall: 0.8995
# Epoch 12/1000
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0879 - accuracy: 0.9524 - precision: 0.8395 - recall: 0.8817 - val_loss: 0.1298 - val_accuracy: 0.9600 - val_precision: 0.8719 - val_recall: 0.8894
# Epoch 13/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0845 - accuracy: 0.9544 - precision: 0.8465 - recall: 0.8862 - val_loss: 0.1253 - val_accuracy: 0.9650 - val_precision: 0.8905 - val_recall: 0.8995
# Epoch 14/1000
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0821 - accuracy: 0.9559 - precision: 0.8504 - recall: 0.8912 - val_loss: 0.1227 - val_accuracy: 0.9608 - val_precision: 0.8689 - val_recall: 0.8995
# Epoch 15/1000
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0804 - accuracy: 0.9561 - precision: 0.8513 - recall: 0.8912 - val_loss: 0.1210 - val_accuracy: 0.9658 - val_precision: 0.8798 - val_recall: 0.9196
# Epoch 16/1000
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0785 - accuracy: 0.9576 - precision: 0.8564 - recall: 0.8951 - val_loss: 0.1164 - val_accuracy: 0.9650 - val_precision: 0.8945 - val_recall: 0.8945
# Epoch 17/1000
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0769 - accuracy: 0.9588 - precision: 0.8600 - recall: 0.8979 - val_loss: 0.1225 - val_accuracy: 0.9642 - val_precision: 0.8578 - val_recall: 0.9397
# Epoch 18/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0764 - accuracy: 0.9598 - precision: 0.8654 - recall: 0.8973 - val_loss: 0.1152 - val_accuracy: 0.9667 - val_precision: 0.8878 - val_recall: 0.9146
# Epoch 19/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0752 - accuracy: 0.9610 - precision: 0.8695 - recall: 0.9001 - val_loss: 0.1130 - val_accuracy: 0.9667 - val_precision: 0.8955 - val_recall: 0.9045
# Epoch 20/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0740 - accuracy: 0.9603 - precision: 0.8690 - recall: 0.8962 - val_loss: 0.1157 - val_accuracy: 0.9667 - val_precision: 0.8804 - val_recall: 0.9246
# Epoch 21/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0738 - accuracy: 0.9627 - precision: 0.8769 - recall: 0.9023 - val_loss: 0.1181 - val_accuracy: 0.9650 - val_precision: 0.8685 - val_recall: 0.9296
# Epoch 22/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0731 - accuracy: 0.9630 - precision: 0.8787 - recall: 0.9018 - val_loss: 0.1097 - val_accuracy: 0.9683 - val_precision: 0.9005 - val_recall: 0.9095
# Epoch 23/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0721 - accuracy: 0.9623 - precision: 0.8770 - recall: 0.8990 - val_loss: 0.1145 - val_accuracy: 0.9667 - val_precision: 0.9119 - val_recall: 0.8844
# Epoch 24/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0718 - accuracy: 0.9632 - precision: 0.8789 - recall: 0.9029 - val_loss: 0.1187 - val_accuracy: 0.9650 - val_precision: 0.8584 - val_recall: 0.9447
# Epoch 25/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0711 - accuracy: 0.9633 - precision: 0.8798 - recall: 0.9023 - val_loss: 0.1164 - val_accuracy: 0.9658 - val_precision: 0.8762 - val_recall: 0.9246
# Epoch 26/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0707 - accuracy: 0.9639 - precision: 0.8822 - recall: 0.9029 - val_loss: 0.1128 - val_accuracy: 0.9650 - val_precision: 0.8756 - val_recall: 0.9196
# Epoch 27/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0703 - accuracy: 0.9635 - precision: 0.8811 - recall: 0.9018 - val_loss: 0.1096 - val_accuracy: 0.9667 - val_precision: 0.8878 - val_recall: 0.9146
# Epoch 28/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0696 - accuracy: 0.9648 - precision: 0.8858 - recall: 0.9046 - val_loss: 0.1109 - val_accuracy: 0.9658 - val_precision: 0.8835 - val_recall: 0.9146
# Epoch 29/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0693 - accuracy: 0.9640 - precision: 0.8836 - recall: 0.9023 - val_loss: 0.1092 - val_accuracy: 0.9675 - val_precision: 0.8922 - val_recall: 0.9146
# Epoch 30/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0689 - accuracy: 0.9644 - precision: 0.8860 - recall: 0.9018 - val_loss: 0.1110 - val_accuracy: 0.9675 - val_precision: 0.8846 - val_recall: 0.9246
# Epoch 31/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0683 - accuracy: 0.9651 - precision: 0.8898 - recall: 0.9012 - val_loss: 0.1124 - val_accuracy: 0.9675 - val_precision: 0.8810 - val_recall: 0.9296
# Epoch 32/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0675 - accuracy: 0.9652 - precision: 0.8904 - recall: 0.9018 - val_loss: 0.1128 - val_accuracy: 0.9658 - val_precision: 0.8762 - val_recall: 0.9246
# Epoch 33/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0677 - accuracy: 0.9647 - precision: 0.8879 - recall: 0.9012 - val_loss: 0.1151 - val_accuracy: 0.9625 - val_precision: 0.8565 - val_recall: 0.9296
# Epoch 34/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0670 - accuracy: 0.9655 - precision: 0.8901 - recall: 0.9040 - val_loss: 0.1090 - val_accuracy: 0.9683 - val_precision: 0.8889 - val_recall: 0.9246
# Epoch 35/1000
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0668 - accuracy: 0.9659 - precision: 0.8908 - recall: 0.9057 - val_loss: 0.1059 - val_accuracy: 0.9667 - val_precision: 0.9077 - val_recall: 0.8894
# Epoch 36/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0663 - accuracy: 0.9659 - precision: 0.8947 - recall: 0.9007 - val_loss: 0.1195 - val_accuracy: 0.9617 - val_precision: 0.8493 - val_recall: 0.9347
# Epoch 37/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0659 - accuracy: 0.9661 - precision: 0.8913 - recall: 0.9062 - val_loss: 0.1049 - val_accuracy: 0.9683 - val_precision: 0.8927 - val_recall: 0.9196
# Epoch 38/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0652 - accuracy: 0.9662 - precision: 0.8931 - recall: 0.9046 - val_loss: 0.1034 - val_accuracy: 0.9683 - val_precision: 0.9086 - val_recall: 0.8995
# Epoch 39/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0650 - accuracy: 0.9666 - precision: 0.8965 - recall: 0.9035 - val_loss: 0.1032 - val_accuracy: 0.9667 - val_precision: 0.8995 - val_recall: 0.8995
# Epoch 40/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0648 - accuracy: 0.9672 - precision: 0.8994 - recall: 0.9035 - val_loss: 0.1023 - val_accuracy: 0.9700 - val_precision: 0.9095 - val_recall: 0.9095
# Epoch 41/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0643 - accuracy: 0.9678 - precision: 0.9007 - recall: 0.9062 - val_loss: 0.1058 - val_accuracy: 0.9658 - val_precision: 0.8873 - val_recall: 0.9095
# Epoch 42/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0640 - accuracy: 0.9669 - precision: 0.8988 - recall: 0.9023 - val_loss: 0.1071 - val_accuracy: 0.9667 - val_precision: 0.8841 - val_recall: 0.9196
# Epoch 43/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0631 - accuracy: 0.9678 - precision: 0.9016 - recall: 0.9046 - val_loss: 0.1070 - val_accuracy: 0.9658 - val_precision: 0.8798 - val_recall: 0.9196
# Epoch 44/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0630 - accuracy: 0.9674 - precision: 0.9013 - recall: 0.9023 - val_loss: 0.1033 - val_accuracy: 0.9683 - val_precision: 0.8927 - val_recall: 0.9196
# Epoch 45/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0627 - accuracy: 0.9687 - precision: 0.9052 - recall: 0.9062 - val_loss: 0.1125 - val_accuracy: 0.9642 - val_precision: 0.8645 - val_recall: 0.9296
# Epoch 46/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0623 - accuracy: 0.9681 - precision: 0.9045 - recall: 0.9035 - val_loss: 0.1032 - val_accuracy: 0.9683 - val_precision: 0.9005 - val_recall: 0.9095
# Epoch 47/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0620 - accuracy: 0.9682 - precision: 0.9045 - recall: 0.9040 - val_loss: 0.1015 - val_accuracy: 0.9692 - val_precision: 0.9263 - val_recall: 0.8844
# Epoch 48/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0612 - accuracy: 0.9692 - precision: 0.9101 - recall: 0.9040 - val_loss: 0.1082 - val_accuracy: 0.9683 - val_precision: 0.8852 - val_recall: 0.9296
# Epoch 49/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0617 - accuracy: 0.9688 - precision: 0.9057 - recall: 0.9062 - val_loss: 0.1016 - val_accuracy: 0.9683 - val_precision: 0.9005 - val_recall: 0.9095
# Epoch 50/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0613 - accuracy: 0.9680 - precision: 0.9031 - recall: 0.9046 - val_loss: 0.1087 - val_accuracy: 0.9658 - val_precision: 0.8726 - val_recall: 0.9296
# Epoch 51/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0608 - accuracy: 0.9692 - precision: 0.9097 - recall: 0.9046 - val_loss: 0.1052 - val_accuracy: 0.9700 - val_precision: 0.9358 - val_recall: 0.8794
# Epoch 52/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0608 - accuracy: 0.9691 - precision: 0.9069 - recall: 0.9074 - val_loss: 0.0999 - val_accuracy: 0.9658 - val_precision: 0.8911 - val_recall: 0.9045
# Epoch 53/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0602 - accuracy: 0.9685 - precision: 0.9056 - recall: 0.9046 - val_loss: 0.0998 - val_accuracy: 0.9642 - val_precision: 0.8900 - val_recall: 0.8945
# Epoch 54/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0599 - accuracy: 0.9701 - precision: 0.9143 - recall: 0.9046 - val_loss: 0.1095 - val_accuracy: 0.9658 - val_precision: 0.8692 - val_recall: 0.9347
# Epoch 55/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0597 - accuracy: 0.9699 - precision: 0.9118 - recall: 0.9062 - val_loss: 0.1022 - val_accuracy: 0.9708 - val_precision: 0.9409 - val_recall: 0.8794
# Epoch 56/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0595 - accuracy: 0.9702 - precision: 0.9134 - recall: 0.9062 - val_loss: 0.1158 - val_accuracy: 0.9633 - val_precision: 0.8571 - val_recall: 0.9347
# Epoch 57/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0586 - accuracy: 0.9692 - precision: 0.9087 - recall: 0.9057 - val_loss: 0.0973 - val_accuracy: 0.9708 - val_precision: 0.9271 - val_recall: 0.8945
# Epoch 58/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0588 - accuracy: 0.9698 - precision: 0.9123 - recall: 0.9051 - val_loss: 0.0994 - val_accuracy: 0.9675 - val_precision: 0.9000 - val_recall: 0.9045
# Epoch 59/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0582 - accuracy: 0.9708 - precision: 0.9151 - recall: 0.9085 - val_loss: 0.1123 - val_accuracy: 0.9650 - val_precision: 0.8651 - val_recall: 0.9347
# Epoch 60/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0585 - accuracy: 0.9701 - precision: 0.9129 - recall: 0.9062 - val_loss: 0.0985 - val_accuracy: 0.9683 - val_precision: 0.9086 - val_recall: 0.8995
# Epoch 61/1000
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0579 - accuracy: 0.9707 - precision: 0.9179 - recall: 0.9046 - val_loss: 0.1015 - val_accuracy: 0.9692 - val_precision: 0.9402 - val_recall: 0.8693
# Epoch 62/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0577 - accuracy: 0.9706 - precision: 0.9150 - recall: 0.9074 - val_loss: 0.0980 - val_accuracy: 0.9692 - val_precision: 0.9175 - val_recall: 0.8945
# Epoch 63/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0574 - accuracy: 0.9704 - precision: 0.9149 - recall: 0.9062 - val_loss: 0.1008 - val_accuracy: 0.9692 - val_precision: 0.9010 - val_recall: 0.9146
# Epoch 64/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0572 - accuracy: 0.9702 - precision: 0.9139 - recall: 0.9057 - val_loss: 0.1011 - val_accuracy: 0.9675 - val_precision: 0.8960 - val_recall: 0.9095
# Epoch 65/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0566 - accuracy: 0.9704 - precision: 0.9140 - recall: 0.9074 - val_loss: 0.1059 - val_accuracy: 0.9675 - val_precision: 0.8846 - val_recall: 0.9246
# Epoch 66/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0567 - accuracy: 0.9705 - precision: 0.9154 - recall: 0.9062 - val_loss: 0.0983 - val_accuracy: 0.9692 - val_precision: 0.9263 - val_recall: 0.8844
# Epoch 67/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0564 - accuracy: 0.9720 - precision: 0.9223 - recall: 0.9079 - val_loss: 0.1048 - val_accuracy: 0.9692 - val_precision: 0.8857 - val_recall: 0.9347
# Epoch 68/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0558 - accuracy: 0.9719 - precision: 0.9199 - recall: 0.9102 - val_loss: 0.1135 - val_accuracy: 0.9667 - val_precision: 0.8698 - val_recall: 0.9397
# Epoch 69/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0559 - accuracy: 0.9705 - precision: 0.9140 - recall: 0.9079 - val_loss: 0.1055 - val_accuracy: 0.9642 - val_precision: 0.8714 - val_recall: 0.9196
# Epoch 70/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0556 - accuracy: 0.9718 - precision: 0.9189 - recall: 0.9107 - val_loss: 0.1018 - val_accuracy: 0.9675 - val_precision: 0.8922 - val_recall: 0.9146
# Epoch 71/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0557 - accuracy: 0.9713 - precision: 0.9191 - recall: 0.9068 - val_loss: 0.0991 - val_accuracy: 0.9667 - val_precision: 0.8955 - val_recall: 0.9045
# Epoch 72/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0549 - accuracy: 0.9718 - precision: 0.9218 - recall: 0.9074 - val_loss: 0.0971 - val_accuracy: 0.9692 - val_precision: 0.9050 - val_recall: 0.9095
# Epoch 73/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0547 - accuracy: 0.9733 - precision: 0.9302 - recall: 0.9074 - val_loss: 0.1001 - val_accuracy: 0.9700 - val_precision: 0.8976 - val_recall: 0.9246
# Epoch 74/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0548 - accuracy: 0.9716 - precision: 0.9207 - recall: 0.9074 - val_loss: 0.0970 - val_accuracy: 0.9683 - val_precision: 0.9086 - val_recall: 0.8995
# Epoch 75/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0541 - accuracy: 0.9719 - precision: 0.9218 - recall: 0.9079 - val_loss: 0.0949 - val_accuracy: 0.9733 - val_precision: 0.9326 - val_recall: 0.9045
# Epoch 76/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0540 - accuracy: 0.9723 - precision: 0.9239 - recall: 0.9079 - val_loss: 0.0961 - val_accuracy: 0.9700 - val_precision: 0.9267 - val_recall: 0.8894
# Epoch 77/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0538 - accuracy: 0.9730 - precision: 0.9271 - recall: 0.9090 - val_loss: 0.1007 - val_accuracy: 0.9683 - val_precision: 0.9005 - val_recall: 0.9095
# Epoch 78/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0535 - accuracy: 0.9721 - precision: 0.9253 - recall: 0.9051 - val_loss: 0.0961 - val_accuracy: 0.9708 - val_precision: 0.9184 - val_recall: 0.9045
# Epoch 79/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0533 - accuracy: 0.9728 - precision: 0.9232 - recall: 0.9118 - val_loss: 0.0945 - val_accuracy: 0.9708 - val_precision: 0.9141 - val_recall: 0.9095
# Epoch 80/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0527 - accuracy: 0.9728 - precision: 0.9256 - recall: 0.9090 - val_loss: 0.0984 - val_accuracy: 0.9717 - val_precision: 0.9104 - val_recall: 0.9196
# Epoch 81/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0527 - accuracy: 0.9732 - precision: 0.9272 - recall: 0.9102 - val_loss: 0.0997 - val_accuracy: 0.9675 - val_precision: 0.8960 - val_recall: 0.9095
# Epoch 82/1000
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0526 - accuracy: 0.9726 - precision: 0.9274 - recall: 0.9057 - val_loss: 0.1029 - val_accuracy: 0.9667 - val_precision: 0.8878 - val_recall: 0.9146
# Epoch 83/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0522 - accuracy: 0.9730 - precision: 0.9262 - recall: 0.9102 - val_loss: 0.0970 - val_accuracy: 0.9675 - val_precision: 0.9167 - val_recall: 0.8844
# Epoch 84/1000
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0515 - accuracy: 0.9734 - precision: 0.9293 - recall: 0.9090 - val_loss: 0.1063 - val_accuracy: 0.9658 - val_precision: 0.8726 - val_recall: 0.9296
# Epoch 85/1000
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0520 - accuracy: 0.9731 - precision: 0.9262 - recall: 0.9107 - val_loss: 0.0970 - val_accuracy: 0.9717 - val_precision: 0.9231 - val_recall: 0.9045
# Epoch 86/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0516 - accuracy: 0.9745 - precision: 0.9327 - recall: 0.9124 - val_loss: 0.1038 - val_accuracy: 0.9675 - val_precision: 0.8883 - val_recall: 0.9196
# Epoch 87/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0513 - accuracy: 0.9738 - precision: 0.9294 - recall: 0.9113 - val_loss: 0.0993 - val_accuracy: 0.9692 - val_precision: 0.9010 - val_recall: 0.9146
# Epoch 88/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0511 - accuracy: 0.9739 - precision: 0.9329 - recall: 0.9079 - val_loss: 0.0982 - val_accuracy: 0.9692 - val_precision: 0.9010 - val_recall: 0.9146
# Epoch 89/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0509 - accuracy: 0.9740 - precision: 0.9310 - recall: 0.9107 - val_loss: 0.1020 - val_accuracy: 0.9700 - val_precision: 0.9553 - val_recall: 0.8593
# Epoch 90/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0508 - accuracy: 0.9745 - precision: 0.9347 - recall: 0.9102 - val_loss: 0.0968 - val_accuracy: 0.9692 - val_precision: 0.9010 - val_recall: 0.9146
# Epoch 91/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0502 - accuracy: 0.9744 - precision: 0.9331 - recall: 0.9113 - val_loss: 0.0962 - val_accuracy: 0.9700 - val_precision: 0.9179 - val_recall: 0.8995
# Epoch 92/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0504 - accuracy: 0.9743 - precision: 0.9321 - recall: 0.9118 - val_loss: 0.0939 - val_accuracy: 0.9717 - val_precision: 0.9412 - val_recall: 0.8844
# Epoch 93/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0501 - accuracy: 0.9741 - precision: 0.9330 - recall: 0.9090 - val_loss: 0.0942 - val_accuracy: 0.9717 - val_precision: 0.9231 - val_recall: 0.9045
# Epoch 94/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0499 - accuracy: 0.9740 - precision: 0.9310 - recall: 0.9107 - val_loss: 0.0976 - val_accuracy: 0.9708 - val_precision: 0.9020 - val_recall: 0.9246
# Epoch 95/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0497 - accuracy: 0.9750 - precision: 0.9369 - recall: 0.9107 - val_loss: 0.0951 - val_accuracy: 0.9700 - val_precision: 0.9137 - val_recall: 0.9045
# Epoch 96/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0495 - accuracy: 0.9747 - precision: 0.9347 - recall: 0.9113 - val_loss: 0.0937 - val_accuracy: 0.9717 - val_precision: 0.9275 - val_recall: 0.8995
# Epoch 97/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0488 - accuracy: 0.9754 - precision: 0.9365 - recall: 0.9141 - val_loss: 0.0974 - val_accuracy: 0.9708 - val_precision: 0.9316 - val_recall: 0.8894
# Epoch 98/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0489 - accuracy: 0.9753 - precision: 0.9385 - recall: 0.9113 - val_loss: 0.1035 - val_accuracy: 0.9683 - val_precision: 0.8966 - val_recall: 0.9146
# Epoch 99/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0489 - accuracy: 0.9753 - precision: 0.9390 - recall: 0.9107 - val_loss: 0.1012 - val_accuracy: 0.9692 - val_precision: 0.9010 - val_recall: 0.9146
# Epoch 100/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0486 - accuracy: 0.9754 - precision: 0.9370 - recall: 0.9135 - val_loss: 0.0949 - val_accuracy: 0.9717 - val_precision: 0.9459 - val_recall: 0.8794
# Epoch 101/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0482 - accuracy: 0.9764 - precision: 0.9414 - recall: 0.9146 - val_loss: 0.1019 - val_accuracy: 0.9658 - val_precision: 0.9247 - val_recall: 0.8643
# Epoch 102/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0485 - accuracy: 0.9753 - precision: 0.9380 - recall: 0.9113 - val_loss: 0.0986 - val_accuracy: 0.9708 - val_precision: 0.9505 - val_recall: 0.8693
# Epoch 103/1000
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0475 - accuracy: 0.9761 - precision: 0.9408 - recall: 0.9135 - val_loss: 0.0952 - val_accuracy: 0.9708 - val_precision: 0.9141 - val_recall: 0.9095
# Epoch 104/1000
# 169/169 [==============================] - 1s 6ms/step - loss: 0.0479 - accuracy: 0.9754 - precision: 0.9390 - recall: 0.9113 - val_loss: 0.0971 - val_accuracy: 0.9717 - val_precision: 0.9188 - val_recall: 0.9095
# Epoch 105/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0478 - accuracy: 0.9759 - precision: 0.9418 - recall: 0.9113 - val_loss: 0.0975 - val_accuracy: 0.9700 - val_precision: 0.9055 - val_recall: 0.9146
# Epoch 106/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0471 - accuracy: 0.9751 - precision: 0.9369 - recall: 0.9113 - val_loss: 0.0992 - val_accuracy: 0.9708 - val_precision: 0.9227 - val_recall: 0.8995
# Epoch 107/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0472 - accuracy: 0.9753 - precision: 0.9425 - recall: 0.9062 - val_loss: 0.1007 - val_accuracy: 0.9700 - val_precision: 0.9095 - val_recall: 0.9095
# Epoch 108/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0474 - accuracy: 0.9762 - precision: 0.9408 - recall: 0.9141 - val_loss: 0.0969 - val_accuracy: 0.9692 - val_precision: 0.9050 - val_recall: 0.9095
# Epoch 109/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0468 - accuracy: 0.9771 - precision: 0.9458 - recall: 0.9146 - val_loss: 0.0945 - val_accuracy: 0.9742 - val_precision: 0.9421 - val_recall: 0.8995
# Epoch 110/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0469 - accuracy: 0.9774 - precision: 0.9459 - recall: 0.9163 - val_loss: 0.1012 - val_accuracy: 0.9692 - val_precision: 0.9091 - val_recall: 0.9045
# Epoch 111/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0467 - accuracy: 0.9770 - precision: 0.9442 - recall: 0.9157 - val_loss: 0.0958 - val_accuracy: 0.9717 - val_precision: 0.9319 - val_recall: 0.8945
# Epoch 112/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0460 - accuracy: 0.9771 - precision: 0.9447 - recall: 0.9157 - val_loss: 0.0942 - val_accuracy: 0.9725 - val_precision: 0.9235 - val_recall: 0.9095
# Epoch 113/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0462 - accuracy: 0.9771 - precision: 0.9452 - recall: 0.9152 - val_loss: 0.0951 - val_accuracy: 0.9717 - val_precision: 0.9275 - val_recall: 0.8995
# Epoch 114/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0457 - accuracy: 0.9766 - precision: 0.9441 - recall: 0.9135 - val_loss: 0.1024 - val_accuracy: 0.9683 - val_precision: 0.8966 - val_recall: 0.9146
# Epoch 115/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0457 - accuracy: 0.9765 - precision: 0.9420 - recall: 0.9146 - val_loss: 0.0937 - val_accuracy: 0.9733 - val_precision: 0.9372 - val_recall: 0.8995
# Epoch 116/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0460 - accuracy: 0.9773 - precision: 0.9443 - recall: 0.9174 - val_loss: 0.0925 - val_accuracy: 0.9725 - val_precision: 0.9278 - val_recall: 0.9045
# Epoch 117/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0455 - accuracy: 0.9769 - precision: 0.9431 - recall: 0.9163 - val_loss: 0.0955 - val_accuracy: 0.9725 - val_precision: 0.9278 - val_recall: 0.9045
# Epoch 118/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0453 - accuracy: 0.9774 - precision: 0.9474 - recall: 0.9146 - val_loss: 0.0972 - val_accuracy: 0.9717 - val_precision: 0.9231 - val_recall: 0.9045
# Epoch 119/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0454 - accuracy: 0.9772 - precision: 0.9453 - recall: 0.9157 - val_loss: 0.0978 - val_accuracy: 0.9700 - val_precision: 0.9095 - val_recall: 0.9095
# Epoch 120/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0448 - accuracy: 0.9781 - precision: 0.9513 - recall: 0.9152 - val_loss: 0.0974 - val_accuracy: 0.9717 - val_precision: 0.9188 - val_recall: 0.9095
# Epoch 121/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0451 - accuracy: 0.9776 - precision: 0.9490 - recall: 0.9141 - val_loss: 0.1002 - val_accuracy: 0.9700 - val_precision: 0.9095 - val_recall: 0.9095
# Epoch 122/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0447 - accuracy: 0.9771 - precision: 0.9458 - recall: 0.9146 - val_loss: 0.0974 - val_accuracy: 0.9717 - val_precision: 0.9558 - val_recall: 0.8693
# Epoch 123/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0446 - accuracy: 0.9777 - precision: 0.9485 - recall: 0.9152 - val_loss: 0.0976 - val_accuracy: 0.9692 - val_precision: 0.9050 - val_recall: 0.9095
# Epoch 124/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0444 - accuracy: 0.9772 - precision: 0.9437 - recall: 0.9174 - val_loss: 0.0985 - val_accuracy: 0.9750 - val_precision: 0.9617 - val_recall: 0.8844
# Epoch 125/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0443 - accuracy: 0.9779 - precision: 0.9486 - recall: 0.9169 - val_loss: 0.0974 - val_accuracy: 0.9708 - val_precision: 0.9184 - val_recall: 0.9045
# Epoch 126/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0442 - accuracy: 0.9779 - precision: 0.9466 - recall: 0.9191 - val_loss: 0.0980 - val_accuracy: 0.9725 - val_precision: 0.9415 - val_recall: 0.8894
# Epoch 127/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0443 - accuracy: 0.9778 - precision: 0.9496 - recall: 0.9146 - val_loss: 0.0969 - val_accuracy: 0.9717 - val_precision: 0.9231 - val_recall: 0.9045
# Epoch 128/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0440 - accuracy: 0.9779 - precision: 0.9476 - recall: 0.9174 - val_loss: 0.1047 - val_accuracy: 0.9692 - val_precision: 0.9010 - val_recall: 0.9146
# Epoch 129/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0437 - accuracy: 0.9774 - precision: 0.9459 - recall: 0.9163 - val_loss: 0.1033 - val_accuracy: 0.9733 - val_precision: 0.9718 - val_recall: 0.8643
# Epoch 130/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0436 - accuracy: 0.9783 - precision: 0.9524 - recall: 0.9152 - val_loss: 0.0957 - val_accuracy: 0.9708 - val_precision: 0.9141 - val_recall: 0.9095
# Epoch 131/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0436 - accuracy: 0.9771 - precision: 0.9489 - recall: 0.9113 - val_loss: 0.0978 - val_accuracy: 0.9708 - val_precision: 0.9184 - val_recall: 0.9045
# Epoch 132/1000
# 169/169 [==============================] - 1s 5ms/step - loss: 0.0433 - accuracy: 0.9779 - precision: 0.9476 - recall: 0.9174 - val_loss: 0.0943 - val_accuracy: 0.9742 - val_precision: 0.9468 - val_recall: 0.8945
# Epoch 133/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0431 - accuracy: 0.9790 - precision: 0.9521 - recall: 0.9196 - val_loss: 0.0948 - val_accuracy: 0.9733 - val_precision: 0.9514 - val_recall: 0.8844
# Epoch 134/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0427 - accuracy: 0.9777 - precision: 0.9485 - recall: 0.9152 - val_loss: 0.0993 - val_accuracy: 0.9742 - val_precision: 0.9615 - val_recall: 0.8794
# Epoch 135/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0430 - accuracy: 0.9783 - precision: 0.9508 - recall: 0.9169 - val_loss: 0.1136 - val_accuracy: 0.9650 - val_precision: 0.8720 - val_recall: 0.9246
# Epoch 136/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0430 - accuracy: 0.9780 - precision: 0.9486 - recall: 0.9174 - val_loss: 0.0943 - val_accuracy: 0.9750 - val_precision: 0.9519 - val_recall: 0.8945
# Epoch 137/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0428 - accuracy: 0.9785 - precision: 0.9514 - recall: 0.9174 - val_loss: 0.0939 - val_accuracy: 0.9733 - val_precision: 0.9326 - val_recall: 0.9045
# Epoch 138/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0426 - accuracy: 0.9788 - precision: 0.9510 - recall: 0.9196 - val_loss: 0.0982 - val_accuracy: 0.9733 - val_precision: 0.9372 - val_recall: 0.8995
# Epoch 139/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0424 - accuracy: 0.9783 - precision: 0.9513 - recall: 0.9163 - val_loss: 0.0956 - val_accuracy: 0.9733 - val_precision: 0.9326 - val_recall: 0.9045
# Epoch 140/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0425 - accuracy: 0.9781 - precision: 0.9497 - recall: 0.9169 - val_loss: 0.0996 - val_accuracy: 0.9742 - val_precision: 0.9330 - val_recall: 0.9095
# Epoch 141/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0422 - accuracy: 0.9788 - precision: 0.9504 - recall: 0.9202 - val_loss: 0.1011 - val_accuracy: 0.9683 - val_precision: 0.9045 - val_recall: 0.9045
# Epoch 142/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0421 - accuracy: 0.9779 - precision: 0.9491 - recall: 0.9157 - val_loss: 0.1075 - val_accuracy: 0.9700 - val_precision: 0.9055 - val_recall: 0.9146
# Epoch 143/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0419 - accuracy: 0.9791 - precision: 0.9521 - recall: 0.9202 - val_loss: 0.0972 - val_accuracy: 0.9725 - val_precision: 0.9278 - val_recall: 0.9045
# Epoch 144/1000
# 169/169 [==============================] - 1s 4ms/step - loss: 0.0417 - accuracy: 0.9797 - precision: 0.9544 - recall: 0.9219 - val_loss: 0.0981 - val_accuracy: 0.9742 - val_precision: 0.9719 - val_recall: 0.8693
# Epoch 145/1000
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0418 - accuracy: 0.9787 - precision: 0.9525 - recall: 0.9174 - val_loss: 0.0958 - val_accuracy: 0.9733 - val_precision: 0.9326 - val_recall: 0.9045
# Epoch 146/1000
# 156/169 [==========================>...] - ETA: 0s - loss: 0.0420 - accuracy: 0.9787 - precision: 0.9518 - recall: 0.9179Restoring model weights from the end of the best epoch: 116.
# 169/169 [==============================] - 1s 3ms/step - loss: 0.0421 - accuracy: 0.9786 - precision: 0.9514 - recall: 0.9180 - val_loss: 0.0968 - val_accuracy: 0.9742 - val_precision: 0.9330 - val_recall: 0.9095
# Epoch 146: early stopping

# %%
loss_df = pd.DataFrame(model.history.history)
loss_df.tail()
# Out:
#      loss  accuracy  precision  recall  val_loss  val_accuracy  val_precision  \
# 141 0.042     0.978      0.949   0.916     0.107         0.970          0.905
# 142 0.042     0.979      0.952   0.920     0.097         0.973          0.928
# 143 0.042     0.980      0.954   0.922     0.098         0.974          0.972
# 144 0.042     0.979      0.952   0.917     0.096         0.973          0.933
# 145 0.042     0.979      0.951   0.918     0.097         0.974          0.933
#
#      val_recall
# 141       0.915
# 142       0.905
# 143       0.869
# 144       0.905
# 145       0.910

# %%
loss_df.plot(subplots=[['loss','val_loss'],
                       ['accuracy','val_accuracy'],
                       ['precision', 'val_precision'],
                       ['recall', 'val_recall']],
                       layout=(2,2),
                       figsize=(12,6));

# %%
loss, accuracy, precision, recall = model.evaluate(X_test, y_test, verbose=0)
print("test loss: ", loss)
print("test accuracy: ", accuracy)
print("test precision ", precision)
print("test recall: ", recall)
# Out:
# test loss:  0.09254588931798935
# test accuracy:  0.9725000262260437
# test precision  0.9278350472450256
# test recall:  0.9045225977897644

# %%
loss, accuracy, precision, recall = model.evaluate(X_train, y_train, verbose=0)
print("train loss: ", loss)
print("train accuracy: ", accuracy)
print("train precision ", precision)
print("train recall: ", recall)
# Out:
# train loss:  0.07386533170938492
# train accuracy:  0.9794272780418396
# train precision  0.9574592113494873
# train recall:  0.9168526530265808

# %%
con_matrix(X_train, X_test, y_train, y_test, model, 'Best Model')
# Out:
# 38/38 [==============================] - 0s 2ms/step
# Best Model - Test Confusion Matrix
# **************************************************
# [[987  14]
#  [ 19 180]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      1001
#            1       0.93      0.90      0.92       199
#
#     accuracy                           0.97      1200
#    macro avg       0.95      0.95      0.95      1200
# weighted avg       0.97      0.97      0.97      1200
#
#
# 338/338 [==============================] - 1s 2ms/step
# Best Model - Train Confusion Matrix
# **************************************************
# [[8926   73]
#  [ 149 1643]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      8999
#            1       0.96      0.92      0.94      1792
#
#     accuracy                           0.98     10791
#    macro avg       0.97      0.95      0.96     10791
# weighted avg       0.98      0.98      0.98     10791

# %%
y_pred_proba = model.predict(X_test)
y_pred_proba_train = model.predict(X_train)

y_pred =  (model.predict(X_test) > .5).astype("int32")
y_pred_train =  (model.predict(X_train) > .5).astype("int32")

print("Average Test Precision Score:  ", average_precision_score(y_test, y_pred_proba))
print("Average Train Precision Score: ", average_precision_score(y_train, y_pred_proba_train))
print("F1 Test Precision Score: ", f1_score(y_test, y_pred))
print("F1 Train Precision Score:",f1_score(y_train, y_pred_train))
print("Recall Test Precision Score: ", recall_score(y_test, y_pred))
print("Recall Train Precision Score:",recall_score(y_train, y_pred_train))
# Out:
# 38/38 [==============================] - 0s 2ms/step
# 338/338 [==============================] - 1s 2ms/step
# 38/38 [==============================] - 0s 2ms/step
# 338/338 [==============================] - 1s 2ms/step
# Average Test Precision Score:   0.9593409624038663
# Average Train Precision Score:  0.9709935715515776
# F1 Test Precision Score:  0.916030534351145
# F1 Train Precision Score: 0.9367160775370582
# Recall Test Precision Score:  0.9045226130653267
# Recall Train Precision Score: 0.9168526785714286

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

# ROC curve for the test data
RocCurveDisplay.from_predictions(y_test, y_pred_proba, ax=axes[0])
axes[0].set_title('Test ROC Curve')

# ROC curve for the train data
RocCurveDisplay.from_predictions(y_train, y_pred_proba_train, ax=axes[1])
axes[1].set_title('Train ROC Curve')
plt.tight_layout();

# %%
plt.figure(figsize=(12, 6))

# Precision-recall curve for the test data
precisions_test, recalls_test, thresholds_test = precision_recall_curve(y_test, y_pred_proba)
plt.subplot(1, 2, 1)  # Arrange two plots side by side, this is the first plot
plt.plot(recalls_test, precisions_test, label='ANN')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (Test)')

# Precision-recall curve for the train data
precisions_train, recalls_train, thresholds_train = precision_recall_curve(y_train, y_pred_proba_train)
plt.subplot(1, 2, 2)  # Arrange two plots side by side, this is the second plot
plt.plot(recalls_train, precisions_train, label='ANN')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve (Train)')

plt.tight_layout();

# %% [markdown]
# ##  8.2. Prediction
# - Make a demo prediction

# %%
df_predict = df.sample(n=5, random_state=seed)
df_predict.head()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 396                0.090            0.790               6
# 3098               0.740            0.960               4
# 9322               0.810            0.970               4
# 357                0.370            0.540               2
# 1323               0.100            0.770               6
#
#       average_montly_hours  time_spend_company  work_accident  left  \
# 396                    293                   5              0     1
# 3098                   154                   4              0     0
# 9322                   212                   2              0     0
# 357                    149                   3              0     1
# 1323                   272                   4              0     1
#
#       promotion_last_5years departments  salary
# 396                       0       sales     low
# 3098                      0     support  medium
# 9322                      0       sales     low
# 357                       0     support     low
# 1323                      0  accounting     low

# %%
X_new = df_predict.drop(['left'], axis=1)
y_new = df_predict['left']

# %%
X_new.head()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 396                0.090            0.790               6
# 3098               0.740            0.960               4
# 9322               0.810            0.970               4
# 357                0.370            0.540               2
# 1323               0.100            0.770               6
#
#       average_montly_hours  time_spend_company  work_accident  \
# 396                    293                   5              0
# 3098                   154                   4              0
# 9322                   212                   2              0
# 357                    149                   3              0
# 1323                   272                   4              0
#
#       promotion_last_5years departments  salary
# 396                       0       sales     low
# 3098                      0     support  medium
# 9322                      0       sales     low
# 357                       0     support     low
# 1323                      0  accounting     low

# %%
y_new.head()
# Out:
# 396     1
# 3098    0
# 9322    0
# 357     1
# 1323    1
# Name: left, dtype: int64

# %%
#ordinal encoding for salary column
X_new['salary'] = ordinal.transform(X_new[['salary']])

X_new.head()
# Out:
#       satisfaction_level  last_evaluation  number_project  \
# 396                0.090            0.790               6
# 3098               0.740            0.960               4
# 9322               0.810            0.970               4
# 357                0.370            0.540               2
# 1323               0.100            0.770               6
#
#       average_montly_hours  time_spend_company  work_accident  \
# 396                    293                   5              0
# 3098                   154                   4              0
# 9322                   212                   2              0
# 357                    149                   3              0
# 1323                   272                   4              0
#
#       promotion_last_5years departments  salary
# 396                       0       sales   0.000
# 3098                      0     support   1.000
# 9322                      0       sales   0.000
# 357                       0     support   0.000
# 1323                      0  accounting   0.000

# %%
transformed_data = pd.DataFrame(col_transformer.transform(X_new))
transformed_data.columns = col_transformer.get_feature_names_out(input_features=X_new.columns )

transformed_data.columns =  [col.split('__')[-1] for col in transformed_data.columns]
X_new = transformed_data
X_new.head()
# Out:
#    departments_RandD  departments_accounting  departments_hr  \
# 0              0.000                   0.000           0.000
# 1              0.000                   0.000           0.000
# 2              0.000                   0.000           0.000
# 3              0.000                   0.000           0.000
# 4              0.000                   1.000           0.000
#
#    departments_management  departments_marketing  departments_product_mng  \
# 0                   0.000                  0.000                    0.000
# 1                   0.000                  0.000                    0.000
# 2                   0.000                  0.000                    0.000
# 3                   0.000                  0.000                    0.000
# 4                   0.000                  0.000                    0.000
#
#    departments_sales  departments_support  departments_technical  \
# 0              1.000                0.000                  0.000
# 1              0.000                1.000                  0.000
# 2              1.000                0.000                  0.000
# 3              0.000                1.000                  0.000
# 4              0.000                0.000                  0.000
#
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0               0.000            0.672           0.800                 0.921
# 1               0.714            0.938           0.400                 0.271
# 2               0.791            0.953           0.400                 0.542
# 3               0.308            0.281           0.000                 0.248
# 4               0.011            0.641           0.800                 0.822
#
#    time_spend_company  work_accident  promotion_last_5years  salary
# 0               0.375          0.000                  0.000   0.000
# 1               0.250          0.000                  0.000   0.500
# 2               0.000          0.000                  0.000   0.000
# 3               0.125          0.000                  0.000   0.000
# 4               0.250          0.000                  0.000   0.000

# %%
# Final Model selection :optuna with Early Stop
  # 'n_units1': 72,
  # 'n_units2': 34,
  # 'n_units3': 16,
  # 'n_units4': 13,
  # 'optimizer': keras.src.optimizers.rmsprop.RMSprop,
  # 'learning_rate': 0.000375821142488931,
  # 'w0': 0.5019737775357155,
  # 'w1': 0.6318714392969568


prediction = pd.DataFrame(model.predict(X_new) > 0.5, columns=['predict']).astype("int32")

pd.concat([df_predict.reset_index(drop=True), prediction.reset_index(drop=True)], axis=1)
# Out:
# 1/1 [==============================] - 0s 34ms/step
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0               0.090            0.790               6                   293
# 1               0.740            0.960               4                   154
# 2               0.810            0.970               4                   212
# 3               0.370            0.540               2                   149
# 4               0.100            0.770               6                   272
#
#    time_spend_company  work_accident  left  promotion_last_5years departments  \
# 0                   5              0     1                      0       sales
# 1                   4              0     0                      0     support
# 2                   2              0     0                      0       sales
# 3                   3              0     1                      0     support
# 4                   4              0     1                      0  accounting
#
#    salary  predict
# 0     low        1
# 1  medium        0
# 2     low        0
# 3     low        1
# 4     low        1

# %% [markdown]
# ## 8.3. Save and Export the Best Model

# %%
model.save('best_hr_churn.h5')

# %% [markdown]
# ___
#
# <p style="text-align: center;"><img src="https://docs.google.com/uc?id=1lY0Uj5R04yMY3-ZppPWxqCr5pvBLYPnV" class="img-fluid" alt="CLRSWY"></p>
#
# ___
